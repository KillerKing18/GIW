# %% [markdown]
# ### Práctica de Web Scraping
#
# Se va a considerar una página web de wikipedia donde se encuentra un recopilatorio de las pinturas realizadas por Francisco Goya: https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Goya
#
# En esta página aparece una tabla en la que aparece cada pintura junto a información asociada a la pintura.

# %%
from IPython.display import Image
Image(filename='Captura.png')

# %% [markdown]
# La tabla está formada por 6 columnas: Cuadro, Título, Fecha, Dimensiones, Museo y País.
# Observa cómo es la estructura de una fila

# %% [raw]
# <tr>
#
# <td><a href="/wiki/Archivo:El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg" class="image"><img alt="El apóstol Santiago y sus discípulos adorando a la Virgen del Pilar.jpg" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg/150px-El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg" width="150" height="195" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg/225px-El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f1/El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg/300px-El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg 2x" data-file-width="2328" data-file-height="3028" /></a>
# </td>
#
# <td><i><a href="/w/index.php?title=El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar&amp;action=edit&amp;redlink=1" class="new" title="El apóstol Santiago y sus discípulos adorando a la Virgen del Pilar (aún no redactado)">El apóstol Santiago y sus discípulos adorando a la Virgen del Pilar</a></i></td>
#
#
# <td><a href="/wiki/1775" title="1775">1775</a>-<a href="/wiki/1780" title="1780">80</a></td>
#
# <td>107 × 80 cm</td>
#
# <td>colección privada</td>
#
# <td><span style="display:none;">España</span><span class="flagicon"><img alt="Flag of Spain.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Flag_of_Spain.svg/20px-Flag_of_Spain.svg.png" width="20" height="13" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Flag_of_Spain.svg/30px-Flag_of_Spain.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Flag_of_Spain.svg/40px-Flag_of_Spain.svg.png 2x" data-file-width="750" data-file-height="500" /></span>&#160;<a href="/wiki/Espa%C3%B1a" title="España">España</a>
# </td>
#
# </tr>

# %% [markdown]
# Los enlaces a las imágenes se encuentran en el atributo src del elemento <img>. En el ejemplo anterior, el valor de src es:
# //upload.wikimedia.org/wikipedia/commons/thumb/f/f1/El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg/150px-El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg
#
# Para acceder a la imagen se debe añadir https: delante del valor recuperado:
#
# https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg/150px-El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg

# %% [markdown]
# Para recuperar el contenido de la página html de wikipedia, se puede hacer de la siguiente manera:

# %%
import requests
url="https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Goya"
r = requests.get(url)
html = r.text
print(html)

# %% [markdown]
# Se pide hacer un buscador que permita recuperar información de la página. Para ello se le mostrará al usuario dos opciones entre las que tiene que elegir: Buscar por país o Buscar por museo.
#
# __Buscar por país[5 puntos] __
#
# Si elige esta opción se le mostrará un listado de todos los paises en los que existe una pintura de Goya. Para facilitar la selección se asignará un número a cada páis, de manera que el usuario elija por número. Los países se pueden recuperar de la última columna de la tabla de la página de wikipedia. Una vez elegido el país, el programa mostrará una lista de todas las pinturas que cumplen ese requisito. De cada pintura se mostrará la información que aparece en las columnas: Título, Fecha, Dimensiones, y Museo. Así mismo, se creará una carpeta en el sistema de archivos, y se guardarán todas las imagenes de las pinturas que cumplen la condición de búsqueda sobre país.
#
# __Buscar por museo[5 puntos] __
#
# Si elige esta opción se le mostrará un listado de todos los museos en los que existe una pintura de Goya. Para facilitar la selección se asignará un número a cada museo, de manera que el usuario elija por número. Los museos se pueden recuperar de la penúltima columna de la tabla de la página de wikipedia. Una vez elegido el museo, el programa mostrará una lista de todas las pinturas que cumplen ese requisito. De cada pintura se mostrará la información que aparece en las columnas: Título, Fecha, Dimensiones, y País. Así mismo, se creará una carpeta en el sistema de archivos, y se guardarán todas las imagenes de las pinturas que cumplen la condición de búsqueda sobre museo.
#
# __Nota: Para procesar la página html es obligatorio utilizar la libreria BeautifulSoup. No se pueden usar otras librerías no vistas en clase__

# %%
#Elige opcion
option = menu()

import urllib
import requests
from bs4 import BeautifulSoup
url = "https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Goya"
r = requests.get(url)
html = r.text

soup = BeautifulSoup(html, 'html.parser')

if int(option) == 1:
    buscarPorPais(soup)
else:
    buscarPorMuseo(soup)
# Out:
# MENÚ
# ----
# 1 - Buscar por país
# 2 - Buscar por museo
# ----
# Introduce elección: 2
#
# 1  -  San Juan El Real (Calatayud)
# 2  -  Museo de Zaragoza (desde 1985) procedente de San Juan El Real de Calatayud (1763?-1767) y de la ermita de la Virgen de Jaraba (1767-1985)
# 3  -  Colección privada (Aragón)
# 4  -  Colección Marquesa de las Palmas (Jerez de la Frontera)
# 5  -  Fundación Selgas-Fagalde (Cudillero)
# 6  -  Museo de Zaragoza
# 7  -  Colección particular
# 8  -  Colección José Gudiol (Barcelona)
# 9  -  Colección Félix Palacios Remondo (Zaragoza)
# 10 -  Colección privada
# 11 -  Museo Provincial, Zaragoza
# 12 -  colección privada
# 13 -  Basílica de Nuestra Señora del Pilar (Zaragoza)
# 14 -  Museo del Prado (Madrid)
# 15 -  colección privada (Barcelona)[7]​
# 16 -  Cartuja de Aula Dei (Zaragoza)
# 17 -  Colección privada, Zaragoza
# 18 -  Museo Goya
# 19 -  Museo de Huesca
# 20 -  Meadows Museum (Dallas)
# 21 -  Real Academia de Bellas Artes San Carlos
# 22 -  Banco de España
# 23 -  Museo Zuloaga
# 24 -  Alte Pinakothek (Múnich)
# 25 -  Colección Pérez Simón
# 26 -  Prado
# 27 -  Colección duques de Sueca
# 28 -  National Gallery of Art (Washington)
# 29 -  Galeria Uffizi
# 30 -  Fundación Magnani-Rocca
# 31 -  Banco de España (Madrid)
# 32 -  Iglesia de San Francisco el Grande (Madrid)
# 33 -  Nationalmuseum (Estocolmo)
# 34 -  Museo Nacional de Escultura, depositado en Museo de Bellas Artes de Asturias
# 35 -  Colección March (Palma de Mallorca)
# 36 -  Galería Nacional de Arte (Washington DC)
# 37 -  Colección privada (Madrid)
# 38 -  Grupo Planeta Corporación
# 39 -  Paradero desconocido
# 40 -  Museo de Bellas Artes de Valencia
# 41 -  Colección Argentaria, Banco Exterior de España (Madrid)
# 42 -  Metropolitan Museum of Art
# 43 -  Kolekcja prywatna
# 44 -  Museo Metropolitano de Arte (Nueva York)
# 45 -  Real Monasterio de San Joaquín y Santa Ana (Valladolid)
# 46 -  Catedral de Valencia (Valencia)
# 47 -  Colección Marquesa Santa Cruz (Madrid)
# 48 -  Real Academia de la Historia (Madrid)
# 49 -  Colección privada dquesa de Villahermosa (Madrid)
# 50 -  Museo de Arte de Ponce (Puerto Rico)
# 51 -  Real Academia de Bellas Artes de San Fernando (Madrid)
# 52 -  Museo de Arte (São Paulo)
# 53 -  Real Academia de San Fernando (Madrid)
# 54 -  Museo del Louvre
# 55 -  Metropolitan Museum of Art (Nueva York)
# 56 -  Szépmuvészeti Múzeum (Budapest)
# 57 -  British Rail Pens on Trustee Co (Londres)
# 58 -  Colección Marqués de Oquendo (Madrid)
# 59 -  Colección José Varez (San Sebastián)
# 60 -  Colección Castro Serna (Madrid)
# 61 -  Bowes Museum
# 62 -  Walters Art Museum (Baltimore)
# 63 -  Indianapolis Museum of Art
# 64 -  Fine Arts Museums of San Francisco
# 65 -  Kimbell Art Museum (Fort Worth)
# 66 -  Philadelphia Museum of Art
# 67 -  Musée des beaux-arts de Montréal
# 68 -  Oratorio Santa Cueva (Cádiz)
# 69 -  Museo del Louvre (París)
# 70 -  Fondo Cultural Villar Mir (Madrid)
# 71 -  Art Institute of Chicago
# 72 -  Colección Alba (Madrid)
# 73 -  Hispanic Society (Nueva York)
# 74 -  Museo de Bellas Artes (Bilbao)
# 75 -  Musée des beaux-arts de Strasbourg
# 76 -  Cleveland Museum of Art
# 77 -  Museo Romántico (Madrid)
# 78 -  Norton Simon Foundation
# 79 -  Fundación Lázaro Galdiano (Madrid)
# 80 -  The National Gallery
# 81 -  Museo Goya (Castres)
# 82 -  Museo Thyssen-Bornemisza
# 83 -  Frick Collection
# 84 -  Courtauld Gallery (Londres)
# 85 -  Catedral de Toledo
# 86 -  Real Academia de la Historia
# 87 -  San Antonio de la Florida (Madrid)
# 88 -  MNAC (Barcelona) Legado Cambó
# 89 -  Museo Lázaro Galdiano
# 90 -  Hispanic Society of America (Nueva York)
# 91 -  Palacio Real de Madrid
# 92 -  National Gallery of Ireland
# 93 -  Museo Alma Mater (Zaragoza)
# 94 -  Museum of Fine Arts en Boston
# 95 -  National Gallery of Ireland (Dublin)
# 96 -  Galería de los Uffizi (Florencia)
# 97 -  Museo de Bellas Artes (Besançon)
# 98 -  Real Academia de San Fernando
# 99 -  National Gallery of Art (Washington DC)
# 100 -  Neue Pinakothek (Múnich)
# 101 -  Colección Duques de Fernán Núñez (Madrid)
# 102 -  Detroit Institute of Arts
# 103 -  Frick Collection (Nueva York)
# 104 -  Palacio de Liria (Madrid)
# 105 -  Getty Center
# 106 -  Museo de Navarra
# 107 -  National Gallery (Londres)
# 108 -  Destruido en 1953
# 109 -  Kunsthalle de Hamburgo
# 110 -  Colección IberCaja (Zaragoza)
# 111 -  Norton Simon Museum (Pasadena)
# 112 -  Des Moines Art Center (Des Moines)
# 113 -  Brooklyn Museum (Nueva York)
# 114 -  Norton Simon Foundation (Pasadena)
# 115 -  Louvre
# 116 -  Galería Nacional de Arte (Washington)
# 117 -  Muzeum Sztuk Pięknych w Budapeszcie
# 118 -  Nueva Pinacoteca (Munich)
# 119 -  Colección BBVA (Madrid)
# 120 -  Museo de Bellas Artes (Lille)
# 121 -  Colección Marañón (Madrid)
# 122 -  Museo del Monasterio de Guadalupe (Guadalupe)
# 123 -  Colección B. March (Palma de Mallorca)
# 124 -  Galería Nacional de Irlanda, Dublín
# 125 -  Museo del Hermitage, San Petersburgo
# 126 -  Colección Duque de Alburquerque (Madrid)
# 127 -  Museo de Zaragoza (Zaragoza)
# 128 -  Museu Nacional d'Art de Catalunya
# 129 -  Nelson-Atkins Museum of Art
# 130 -  Galería Nacional (Praga)
# 131 -  Gemäldegalerie (Berlin)
# 132 -  Worcester Art Museum
# 133 -  Museo Bonnat (Bayona)
# 134 -  Metropolitan Museum of Art (Filadelfia)
# 135 -  Museo Lázaro Galdiano (Madrid)
# 136 -  Museo Thyssen-Bornemisza (Madrid)
# 137 -  Catedral de Santa María de la Sede de Sevilla
# 138 -  Escuelas Pías de San Antón (Madrid)
# 139 -  Museo de la Residencia Calasanz (Madrid)
# 140 -  Musée Bonnat-Helle
# 141 -  Colección Frick (Nueva York)
# 142 -  Colección particular (Salamanca)
# 143 -  Instituto de Arte de Minneapolis (Minneapolis)
# 144 -  Colección Phillips (Washington DC)
# 145 -  Rijksmuseum (Ámsterdam)
# 146 -  Museo de Bellas Artes de Sevilla (Sevilla)
# 147 -  Colección privada (Roma)
# 148 -  Museo de Bellas Artes de Bilbao
# 149 -  Princeton University Art Museum
# 150 -  Museo de Bellas Artes (Boston)
# 151 -  Rhode Island School of Design Museum
# 152 -  Museo Nacional de Estocolmo
# 153 -  Gabinete de Grabados de Dresden
# 154 -  Orientalist Museum, Doha
# 155 -  Barnes Foundation (Filadelfia)
# 156 -  Fundación Oskar Reinhart (Winterthur)
# Introduce elección: 6
# Aníbal vencedor contempla por primera vez Italia desde los Alpes (boceto I)
# 1770
# 30,5 × 38,5
# _____________________
# Venus y Adonis
# 1771
# 23 × 12
# _____________________
# Éxtasis de San Antonio Abad
# 1780
# 67 × 46
# _____________________
# La letra con sangre entra
# 1780 - 1785
# 19,7 x 38,7
# _____________________
# Retrato de Luis María de Borbón y Vallabriga, niño
# 1783
# 133 × 114,7
# _____________________
# Carlos IV
# 1790
# 152 × 110
# _____________________
# Maria Luisa de Parma, reina de España
# 1789
# 152 × 110
# _____________________
# Juan Martín de Goicoechea y Galarza
# 1789
# 84 × 65
# _____________________
# San Luis Gonzaga meditando
# 1798–1800
# 261 × 160
# _____________________
# Francisco Javier Goya y Bayeu
# 1805
# 8 c
# _____________________
# Gumersinda Goicoechea
# 1805
# 8 c
# _____________________
# Retrato de dama con mantilla
# 1823–1824
# 61 × 51
# _____________________
# ¿En qué carpeta guardas las imagenes? jjjjjjjjjjjj
# Imagenes guardadas correctamente!

# %%
def menu():
    print("MENÚ")
    print("----")
    print("1 - Buscar por país")
    print("2 - Buscar por museo")
    print("----")
    inputCorrecto = False
    
    while not inputCorrecto:
        elemento = input("Introduce elección: ")
        try:
            if int(elemento) > 0 and int(elemento) < 3:
                inputCorrecto = True
            else:
                print("\nError. Introduce una opción posible.")
        except:
            print("\nError. Introduce un numero correcto.") # Necesitamos numeros
    return elemento

# %%
#Busqueda por pais
def buscarPorPais(soup):
    
    etiquetas = soup("tr")
    print()
    listaSrc = []
    paisDelSrc = {}
    lista = listaPaises(etiquetas, listaSrc, paisDelSrc)

    # Sacamos por pantalla los paises
    i = 1
    for pais in lista:
        if i > 9:
            print(i , "- ", pais)
        else:
            print(i , " - ", pais)
        i = i + 1
        
    #Elige un pais
    elemento = inputUsuario(len(lista))
            
    pinturas = cuadrosPais(lista[int(elemento) - 1], etiquetas)
    
    #Guardo imagenes en carpeta
    guardaCarpeta(lista[int(elemento) - 1], etiquetas, listaSrc, paisDelSrc)

# %%
def listaPaises(etiquetas, listaSrc, paisDelSrc):
    lista = []
    i = 0
    for etiqueta in etiquetas: 
        if i > 0:
            s = 0
            for item in etiqueta:
                if s == 1:
                    pos = str(item).find("src=")
                    elem = str(item)[pos + 5:]
                    pos = elem.find("srcset")
                    elem = str(elem)[:pos - 2]
                    elem = "https:" + elem
                    listaSrc.append(elem)
                if s == 11:
                    newPais = item.text.split()

                    if len(newPais) > 0:
                        aux = newPais[0]
                        if newPais[0] == "República": #Es el único que no está duplicado
                            aux = aux  + " " + newPais[1]
                        if len(newPais) > 2:
                            aux = ""
                            j = 0
                            for member in newPais:
                                if j < len(newPais) / 2:
                                    aux = aux + member + " "
                                j = j + 1
                        paisDelSrc[listaSrc[len(listaSrc)  - 1]] = aux
                        if aux not in lista:   
                            lista.append(aux)
                    else:
                        paisDelSrc[listaSrc[len(listaSrc)  - 1]] = "NADA"
                s = s + 1
        i = i + 1
    return lista

# %%
def cuadrosPais(pais, etiquetas):
    #Se mostrará la información que aparece en las columnas: Título, Fecha, Dimensiones, y Museo
    lista = []
    i = 0
    for etiqueta in etiquetas:
        if i > 0:
            s = 0
            for item in etiqueta:
                if pais[int(len(pais) - 1)] == " ":
                    pais = pais[:int(len(pais) - 1)]
                if s == 11 and len(item.text) > 0 and item.text[:int(len(item.text) / 2 - 1)] == pais:
                    lista.append(etiqueta)
                s = s + 1
        i = i + 1
    
    for etiqueta in lista:
        a = etiqueta.text[:len(etiqueta.text) - 2 * len(pais) - 2].strip()
        print(a)
        print("_____________________")
        
    return True

# %%
import os
import urllib.request
def guardaCarpeta(pais, etiquetas, listaSrc, paisDelSrc):

    path = input("¿En qué carpeta guardas las imagenes? ")
    if not os.path.exists(path):
        try:
            os.makedirs(path)
        except OSError:
            print("Error creatng the folder!")

    os.chdir(path)
    
    #Guardar imagenes
    x = 1
    for url in listaSrc:
        if paisDelSrc[url] == pais:
            img = urllib.request.urlopen(url)
            name = "imagen" + str(x) + ".jpg"
            f = open(name,"wb")
            while True:
                info = img.read(100000)
                if len(info) < 1: 
                    break
                f.write(info)
            f.close()
            x = x + 1
    
    print("Imagenes guardadas correctamente!")

# %%
def inputUsuario(leng):
    inputCorrecto = False
    while not inputCorrecto:
        elemento = input("Introduce elección: ")
        try:
            if int(elemento) > 0 and int(elemento) < leng + 1:
                inputCorrecto = True
            else:
                print("\nError. Introduce una opción posible.")
        except:
            print("\nError. Introduce un numero correcto.") # Necesitamos numeros
    return elemento

# %%
#Busqueda por museo
def buscarPorMuseo(soup):
   
    etiquetas = soup("tr")
    print()
    listaSrc = []
    museoDelSrc = {}
    lista = listaMuseos(etiquetas, listaSrc, museoDelSrc)

    # Sacamos por pantalla los paises
    i = 1
    for pais in lista:
        if i > 9:
            print(i , "- ", pais)
        else:
            print(i , " - ", pais)
        i = i + 1
        
    #Elige un pais
    elemento = inputUsuario(len(lista))
            
    pinturas = cuadrosMuseo(lista[int(elemento) - 1], etiquetas) #TODO 
    
    #Guardo imagenes en carpeta
    guardaCarpeta(lista[int(elemento) - 1], etiquetas, listaSrc, museoDelSrc)

# %%
def listaMuseos(etiquetas, listaSrc, museoDelSrc):
    lista = []
    i = 0
    for etiqueta in etiquetas: 
        if i > 0:
            s = 0
            for item in etiqueta:
                if s == 1:
                    pos = str(item).find("src=")
                    elem = str(item)[pos + 5:]
                    pos = elem.find("srcset")
                    elem = str(elem)[:pos - 2]
                    elem = "https:" + elem
                    listaSrc.append(elem)
                if s == 9:
                    newMuseo = item.text.split()

                    aux = ""
                    if len(newMuseo) > 0:
                        for item in newMuseo:
                            aux =  aux + item + " "
                        museoDelSrc[listaSrc[len(listaSrc)  - 1]] = aux 
            
                        if aux not in lista:   
                            lista.append(aux)
                    else:
                        museoDelSrc[listaSrc[len(listaSrc)  - 1]] = "NADA"
                s = s + 1
        i = i + 1
    return lista

# %%
def cuadrosMuseo(museo, etiquetas):
    #Se mostrará la información que aparece en las columnas: Título, Fecha, Dimensiones, y Museo
    lista = []
    i = 0
    for etiqueta in etiquetas:
        if i > 0:
            s = 0
            for item in etiqueta:
                if museo[int(len(museo) - 1)] == " ":
                    museo = museo[:int(len(museo) - 1)]
                if s == 9 and len(item.text) > 0 and (item.text == museo or item.text[:int(len(item.text) - 1)] == museo):
                    lista.append(etiqueta)
                s = s + 1
        i = i + 1
    
    for etiqueta in lista:
        a = etiqueta.text[:len(etiqueta.text) - 2 * len(museo) - 2].strip()
        print(a)
        print("_____________________")
        
    return True

# %% [raw]
# # Normas de entrega
#
# * Fecha tope de entrega: 28/10/2018
# * La entrega se realizará subiendo al campus virtual un notebook de Jupyter con la solución. El archivo tendrá como nombre WebScraping_GrupoX donde X será el número de grupo correspondiente.
