# %% [markdown]
# ### Práctica de Web Scraping
#
# Se va a considerar una página web de wikipedia donde se encuentra un recopilatorio de las pinturas realizadas por Francisco Goya: https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Goya
#
# En esta página aparece una tabla en la que aparece cada pintura junto a información asociada a la pintura.

# %%
from IPython.display import Image
Image(filename='Captura.png')

# %% [markdown]
# La tabla está formada por 6 columnas: Cuadro, Título, Fecha, Dimensiones, Museo y País.
# Observa cómo es la estructura de una fila

# %% [raw]
# <tr>
#
# <td><a href="/wiki/Archivo:El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg" class="image"><img alt="El apóstol Santiago y sus discípulos adorando a la Virgen del Pilar.jpg" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg/150px-El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg" width="150" height="195" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg/225px-El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f1/El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg/300px-El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg 2x" data-file-width="2328" data-file-height="3028" /></a>
# </td>
#
# <td><i><a href="/w/index.php?title=El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar&amp;action=edit&amp;redlink=1" class="new" title="El apóstol Santiago y sus discípulos adorando a la Virgen del Pilar (aún no redactado)">El apóstol Santiago y sus discípulos adorando a la Virgen del Pilar</a></i></td>
#
#
# <td><a href="/wiki/1775" title="1775">1775</a>-<a href="/wiki/1780" title="1780">80</a></td>
#
# <td>107 × 80 cm</td>
#
# <td>colección privada</td>
#
# <td><span style="display:none;">España</span><span class="flagicon"><img alt="Flag of Spain.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Flag_of_Spain.svg/20px-Flag_of_Spain.svg.png" width="20" height="13" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Flag_of_Spain.svg/30px-Flag_of_Spain.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Flag_of_Spain.svg/40px-Flag_of_Spain.svg.png 2x" data-file-width="750" data-file-height="500" /></span>&#160;<a href="/wiki/Espa%C3%B1a" title="España">España</a>
# </td>
#
# </tr>

# %% [markdown]
# Los enlaces a las imágenes se encuentran en el atributo src del elemento <img>. En el ejemplo anterior, el valor de src es:
# //upload.wikimedia.org/wikipedia/commons/thumb/f/f1/El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg/150px-El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg
#
# Para acceder a la imagen se debe añadir https: delante del valor recuperado:
#
# https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg/150px-El_ap%C3%B3stol_Santiago_y_sus_disc%C3%ADpulos_adorando_a_la_Virgen_del_Pilar.jpg

# %% [markdown]
# Para recuperar el contenido de la página html de wikipedia, se puede hacer de la siguiente manera:

# %%
import requests
url="https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Goya"
r = requests.get(url)
html = r.text
print(html)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="es" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Anexo:Cuadros de Goya - Wikipedia, la enciclopedia libre</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"Anexo","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":104,"wgPageName":"Anexo:Cuadros_de_Goya","wgTitle":"Cuadros de Goya","wgCurRevisionId":111597452,"wgRevisionId":111597452,"wgArticleId":1340353,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:Páginas con enlaces mágicos de ISBN","Cuadros de Francisco de Goya","Rococó","Neoclasicismo","Romanticismo","Anexos:Pintura"],"wgBreakFrames":false,"wgPageContentLanguage":"es","wgPageContentModel":"wikitext","wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgMonthNamesShort":["","ene","feb","mar","abr","may","jun","jul","ago","sep","oct","nov","dic"],"wgRelevantPageName":"Anexo:Cuadros_de_Goya","wgRelevantArticleId":1340353,"wgRequestId":"W9WKbgpAAD8AAGPGIHwAAABX","wgCSPNonce":false,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikiEditorEnabledModules":[],"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es","usePageImages":true,"usePageDescriptions":true},"wgMFExpandAllSectionsUserOption":true,"wgMFEnableFontChanger":true,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"español","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgWikibaseItemId":"Q3543856","wgScoreNoteLanguages":{"arabic":"العربية","catalan":"català","deutsch":"Deutsch","english":"English","espanol":"español","italiano":"italiano","nederlands":"Nederlands","norsk":"norsk","portugues":"português","suomi":"suomi","svenska":"svenska","vlaams":"West-Vlams"},"wgScoreDefaultNoteLanguage":"nederlands","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":true,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true});mw.loader.state({"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"});mw.loader.implement("user.options@00wq302",function($,jQuery,require,module){/*@nomin*/mw.user.options.set({"variant":"es"});
# });mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });RLPAGEMODULES=["ext.cite.a11y","site","mediawiki.page.startup","mediawiki.user","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.a-commons-directo","ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.compactlinks","ext.uls.interface","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];mw.loader.load(RLPAGEMODULES);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=es&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=es&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=es&amp;modules=ext.gadget.imagenesinfobox&amp;only=styles&amp;skin=vector"/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=es&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <noscript><link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=es&amp;modules=noscript&amp;only=styles&amp;skin=vector"/></noscript>
# <meta name="generator" content="MediaWiki 1.33.0-wmf.1"/>
# <meta name="referrer" content="origin"/>
# <meta name="referrer" content="origin-when-crossorigin"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/es.m.wikipedia.org/wiki/Anexo:Cuadros_de_Goya"/>
# <link rel="alternate" type="application/x-wiki" title="Editar" href="/w/index.php?title=Anexo:Cuadros_de_Goya&amp;action=edit"/>
# <link rel="edit" title="Editar" href="/w/index.php?title=Anexo:Cuadros_de_Goya&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (es)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//es.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="license" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Goya"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# <!--[if lt IE 9]><script src="/w/load.php?debug=false&amp;lang=es&amp;modules=html5shiv&amp;only=scripts&amp;skin=vector&amp;sync=1"></script><![endif]-->
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-104 ns-subject page-Anexo_Cuadros_de_Goya rootpage-Anexo_Cuadros_de_Goya skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
# 			<div id="siteNotice" class="mw-body-content"><!-- CentralNotice --></div><div class="mw-indicators mw-body-content">
# </div>
# <h1 id="firstHeading" class="firstHeading" lang="es">Anexo:Cuadros de Goya</h1>			<div id="bodyContent" class="mw-body-content">
# 				<div id="siteSub" class="noprint">De Wikipedia, la enciclopedia libre</div>				<div id="contentSub"></div>
# 				<div id="jump-to-nav"></div>				<a class="mw-jump-link" href="#mw-head">Ir a la navegación</a>
# 				<a class="mw-jump-link" href="#p-search">Ir a la búsqueda</a>
# 				<div id="mw-content-text" lang="es" dir="ltr" class="mw-content-ltr"><div class="mw-parser-output"><div class="thumb tright"><div class="thumbinner" style="width:152px;"><a href="/wiki/Archivo:Vicente_L%C3%B3pez_Porta%C3%B1a_-_el_pintor_Francisco_de_Goya.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Vicente_L%C3%B3pez_Porta%C3%B1a_-_el_pintor_Francisco_de_Goya.jpg/150px-Vicente_L%C3%B3pez_Porta%C3%B1a_-_el_pintor_Francisco_de_Goya.jpg" width="150" height="185" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Vicente_L%C3%B3pez_Porta%C3%B1a_-_el_pintor_Francisco_de_Goya.jpg/225px-Vicente_L%C3%B3pez_Porta%C3%B1a_-_el_pintor_Francisco_de_Goya.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Vicente_L%C3%B3pez_Porta%C3%B1a_-_el_pintor_Francisco_de_Goya.jpg/300px-Vicente_L%C3%B3pez_Porta%C3%B1a_-_el_pintor_Francisco_de_Goya.jpg 2x" data-file-width="2478" data-file-height="3051" /></a>  <div class="thumbcaption"><div class="magnify"><a href="/wiki/Archivo:Vicente_L%C3%B3pez_Porta%C3%B1a_-_el_pintor_Francisco_de_Goya.jpg" class="internal" title="Aumentar"></a></div><a href="/wiki/Retrato_del_pintor_Francisco_de_Goya" class="mw-redirect" title="Retrato del pintor Francisco de Goya">Retrato</a> de <a href="/wiki/Francisco_de_Goya" title="Francisco de Goya">Goya</a> por <a href="/wiki/Vicente_L%C3%B3pez_Porta%C3%B1a" title="Vicente López Portaña">Vicente López Portaña</a>.</div></div></div>
# <p>La <b>carrera artística de <a href="/wiki/Francisco_de_Goya" title="Francisco de Goya">Francisco de Goya</a></b> transcurrió, aproximadamente, entre <a href="/wiki/1762" title="1762">1762</a>, año en que pintó un relicario para la iglesia parroquial de <a href="/wiki/Fuendetodos" title="Fuendetodos">Fuendetodos</a>, y <a href="/wiki/1827" title="1827">1827</a>, fecha de sus últimas obras (<i><a href="/wiki/La_lechera_de_Burdeos" title="La lechera de Burdeos">La lechera de Burdeos</a> </i>). Durante este más de medio siglo como pintor produjo alrededor de setecientas pinturas, doscientos ochenta <a href="/wiki/Aguafuerte" title="Aguafuerte">aguafuertes</a> y unos mil <a href="/wiki/Dibujo" title="Dibujo">dibujos</a>.
# </p><p>Fue un pintor que evolucionó desde <a href="/wiki/Pintura_rococ%C3%B3" title="Pintura rococó">el rococó</a> que impregna sus frescos y cartones para <a href="/wiki/Tapiz" title="Tapiz">tapices</a>, a autor de una obra personalísima como las <i><a href="/wiki/Pinturas_negras" title="Pinturas negras">Pinturas negras</a></i>, pasando por ser pintor de la corte de los reyes <a href="/wiki/Carlos_IV_de_Espa%C3%B1a" title="Carlos IV de España">Carlos IV</a> y <a href="/wiki/Fernando_VII_de_Espa%C3%B1a" title="Fernando VII de España">Fernando VII</a>.
# </p><p>La temática goyesca es amplia: el <a href="/wiki/Retrato" title="Retrato">retrato</a>, la <a href="/wiki/Trabajos_de_g%C3%A9nero" class="mw-redirect" title="Trabajos de género">escena de género</a> (<a href="/wiki/Caza" title="Caza">caza</a>, escenas galantes y populares, vicios de la sociedad, violencia, <a href="/wiki/Brujer%C3%ADa" title="Brujería">brujas</a> y <a href="/wiki/Diablo" title="Diablo">diablos</a>), y también pintura histórica, religiosa y el <a href="/wiki/Bodeg%C3%B3n" title="Bodegón">bodegón</a>.<sup id="cite_ref-1" class="reference separada"><a href="#cite_note-1"><span class="corchete-llamada">[</span>1<span class="corchete-llamada">]</span></a></sup>&#8203;
# </p><p>Es especialmente importante, tanto por el número de obras como por su calidad, la obra conservada en el <a href="/wiki/Museo_del_Prado" title="Museo del Prado">Museo del Prado</a> de <a href="/wiki/Madrid" title="Madrid">Madrid</a>. No obstante, en diversos <a href="/wiki/Museo" title="Museo">museos</a> del mundo se encuentra representado, sobre todo con retratos: la <a href="/wiki/National_Gallery_de_Londres" class="mw-redirect" title="National Gallery de Londres">National Gallery</a> de <a href="/wiki/Londres" title="Londres">Londres</a>, el <a href="/wiki/Museo_Metropolitano_de_Arte" title="Museo Metropolitano de Arte">Museo Metropolitano de Arte</a> de <a href="/wiki/Nueva_York" title="Nueva York">Nueva York</a>, la <a href="/wiki/Galer%C3%ADa_de_los_Uffizi" class="mw-redirect" title="Galería de los Uffizi">Galería de los Uffizi</a>, la <a href="/wiki/Alte_Pinakothek" class="mw-redirect" title="Alte Pinakothek">Alte Pinakothek</a>, etc.<sup id="cite_ref-2" class="reference separada"><a href="#cite_note-2"><span class="corchete-llamada">[</span>2<span class="corchete-llamada">]</span></a></sup>&#8203;
# </p>
# <h2><span class="mw-headline" id="Lista_de_cuadros">Lista de cuadros</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Anexo:Cuadros_de_Goya&amp;action=edit&amp;section=1" title="Editar sección: Lista de cuadros">editar</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>A continuación se pueden apreciar sus cuadros como pintor:<sup id="cite_ref-3" class="reference separada"><a href="#cite_note-3"><span class="corchete-llamada">[</span>3<span class="corchete-llamada">]</span></a></sup>&#8203;<sup id="cite_ref-4" class="reference separada"><a href="#cite_note-4"><span class="corchete-llamada">[</span>4<span class="corchete-llamada">]</span></a></sup>&#8203;
svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/40px-Flag_of_France.svg.png 2x" data-file-width="900" data-file-height="600" />&#160;</span><a href="/wiki/Francia" title="Francia">Francia</a>
# </td></tr>
# <tr>
# ...
# 							</div>
# 		</div>
# 		<div id="mw-navigation">
# 			<h2>Menú de navegación</h2>
# 			<div id="mw-head">
# 									<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">
# 						<h3 id="p-personal-label">Herramientas personales</h3>
# 						<ul>
# 							<li id="pt-anonuserpage">No has accedido</li><li id="pt-anontalk"><a href="/wiki/Especial:MiDiscusi%C3%B3n" title="Discusión sobre ediciones hechas desde esta dirección IP [n]" accesskey="n">Discusión</a></li><li id="pt-anoncontribs"><a href="/wiki/Especial:MisContribuciones" title="Una lista de modificaciones hechas desde esta dirección IP [y]" accesskey="y">Contribuciones</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Especial:Crear_una_cuenta&amp;returnto=Anexo%3ACuadros+de+Goya" title="Te recomendamos crear una cuenta e iniciar sesión; sin embargo, no es obligatorio">Crear una cuenta</a></li><li id="pt-login"><a href="/w/index.php?title=Especial:Entrar&amp;returnto=Anexo%3ACuadros+de+Goya" title="Te recomendamos iniciar sesión, aunque no es obligatorio [o]" accesskey="o">Acceder</a></li>						</ul>
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Espacios de nombres</h3>
# 						<ul>
# 							<li id="ca-nstab-anexo" class="selected"><span><a href="/wiki/Anexo:Cuadros_de_Goya">Anexo</a></span></li><li id="ca-talk"><span><a href="/wiki/Anexo_Discusi%C3%B3n:Cuadros_de_Goya" rel="discussion" title="Discusión acerca de la página [t]" accesskey="t">Discusión</a></span></li>						</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<input type="checkbox" class="vectorMenuCheckbox" aria-labelledby="p-variants-label" />
# 						<h3 id="p-variants-label">
# 							<span>Variantes</span>
# 						</h3>
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Vistas</h3>
# 						<ul>
# 							<li id="ca-view" class="collapsible selected"><span><a href="/wiki/Anexo:Cuadros_de_Goya">Leer</a></span></li><li id="ca-edit" class="collapsible"><span><a href="/w/index.php?title=Anexo:Cuadros_de_Goya&amp;action=edit" title="Editar esta página [e]" accesskey="e">Editar</a></span></li><li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=Anexo:Cuadros_de_Goya&amp;action=history" title="Versiones anteriores de esta página [h]" accesskey="h">Ver historial</a></span></li>						</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<input type="checkbox" class="vectorMenuCheckbox" aria-labelledby="p-cactions-label" />
# 						<h3 id="p-cactions-label"><span>Más</span></h3>
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Buscar</label>
# 						</h3>
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 								<input type="search" name="search" placeholder="Buscar en Wikipedia" title="Buscar en este wiki [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Especial:Buscar" name="title"/><input type="submit" name="fulltext" value="Buscar" title="Busca páginas con este texto." id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Ir" title="Ir a la página con este nombre exacto si existe" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Wikipedia:Portada"  title="Visitar la página principal"></a></div>
# 						<div class="portal" role="navigation" id="p-navigation" aria-labelledby="p-navigation-label">
# 			<h3 id="p-navigation-label">Navegación</h3>
# 			<div class="body">
# 								<ul>
# 					<li id="n-mainpage-description"><a href="/wiki/Wikipedia:Portada" title="Visitar la página principal [z]" accesskey="z">Portada</a></li><li id="n-portal"><a href="/wiki/Portal:Comunidad" title="Acerca del proyecto, lo que puedes hacer, dónde encontrar información">Portal de la comunidad</a></li><li id="n-currentevents"><a href="/wiki/Portal:Actualidad" title="Encuentra información de contexto sobre acontecimientos actuales">Actualidad</a></li><li id="n-recentchanges"><a href="/wiki/Especial:CambiosRecientes" title="Lista de cambios recientes en el wiki [r]" accesskey="r">Cambios recientes</a></li><li id="n-newpages"><a href="/wiki/Especial:P%C3%A1ginasNuevas">Páginas nuevas</a></li><li id="n-randompage"><a href="/wiki/Especial:Aleatoria" title="Cargar una página al azar [x]" accesskey="x">Página aleatoria</a></li><li id="n-help"><a href="/wiki/Ayuda:Contenidos" title="El lugar para aprender">Ayuda</a></li><li id="n-sitesupport"><a href="//donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_es.wikipedia.org&amp;uselang=es" title="Apóyanos">Donaciones</a></li><li id="n-bug_in_article"><a href="/wiki/Wikipedia:Informes_de_error">Notificar un error</a></li>				</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id="p-coll-print_export" aria-labelledby="p-coll-print_export-label">
# 			<h3 id="p-coll-print_export-label">Imprimir/exportar</h3>
# 			<div class="body">
# 								<ul>
# 					<li id="coll-create_a_book"><a href="/w/index.php?title=Especial:Libro&amp;bookcmd=book_creator&amp;referer=Anexo%3ACuadros+de+Goya">Crear un libro</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Especial:ElectronPdf&amp;page=Anexo%3ACuadros+de+Goya&amp;action=show-download-screen">Descargar como PDF</a></li><li id="t-print"><a href="/w/index.php?title=Anexo:Cuadros_de_Goya&amp;printable=yes" title="Versión imprimible de esta página [p]" accesskey="p">Versión para imprimir</a></li>				</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id="p-wikibase-otherprojects" aria-labelledby="p-wikibase-otherprojects-label">
# 			<h3 id="p-wikibase-otherprojects-label">En otros proyectos</h3>
# 			<div class="body">
# 								<ul>
# 					<li class="wb-otherproject-link wb-otherproject-commons"><a href="https://commons.wikimedia.org/wiki/Category:Paintings_by_Francisco_de_Goya" hreflang="en">Wikimedia Commons</a></li><li class="wb-otherproject-link wb-otherproject-wikidata"><a href="https://www.wikidata.org/wiki/Wikidata:WikiProject_sum_of_all_paintings/Creator/Francisco_de_Goya" hreflang="en">Wikidata</a></li>				</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id="p-tb" aria-labelledby="p-tb-label">
# 			<h3 id="p-tb-label">Herramientas</h3>
# 			<div class="body">
# 								<ul>
# 					<li id
# 										<li id="footer-poweredbyico">
# 						<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>					</li>
# 									</ul>
# 						<div style="clear: both;"></div>
# 		</div>
#
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"1.268","walltime":"1.711","ppvisitednodes":{"value":3954,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":62464,"limit":2097152},"templateargumentsize":{"value":376,"limit":2097152},"expansiondepth":{"value":9,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":11200,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  245.035      1 -total"," 37.04%   90.765      1 Plantilla:Listaref"," 21.77%   53.354      4 Plantilla:Cita_web"," 18.26%   44.748      1 Plantilla:Commonscat","  6.72%   16.464    200 Plantilla:ESP","  6.48%   15.878      1 Plantilla:Propiedad","  4.21%   10.317      2 Plantilla:Cita_libro","  3.79%    9.277      7 Plantilla:GBR","  2.91%    7.138      1 Plantilla:Título_sin_coletilla","  2.89%    7.077      1 Plantilla:Bandera2"]},"scribunto":{"limitreport-timeusage":{"value":"0.039","limit":"10.000"},"limitreport-memusage":{"value":2230564,"limit":52428800}},"cachereport":{"origin":"mw1270","timestamp":"20181028100659","ttl":1900800,"transientcontent":false}}});mw.config.set({"wgBackendResponseTime":108,"wgHostname":"mw1268"});});</script>
# 	</body>
# </html>

# %% [markdown]
# Se pide hacer un buscador que permita recuperar información de la página. Para ello se le mostrará al usuario dos opciones entre las que tiene que elegir: Buscar por país o Buscar por museo.
#
# __Buscar por país[5 puntos] __
#
# Si elige esta opción se le mostrará un listado de todos los paises en los que existe una pintura de Goya. Para facilitar la selección se asignará un número a cada páis, de manera que el usuario elija por número. Los países se pueden recuperar de la última columna de la tabla de la página de wikipedia. Una vez elegido el país, el programa mostrará una lista de todas las pinturas que cumplen ese requisito. De cada pintura se mostrará la información que aparece en las columnas: Título, Fecha, Dimensiones, y Museo. Así mismo, se creará una carpeta en el sistema de archivos, y se guardarán todas las imagenes de las pinturas que cumplen la condición de búsqueda sobre país.
#
# __Buscar por museo[5 puntos] __
#
# Si elige esta opción se le mostrará un listado de todos los museos en los que existe una pintura de Goya. Para facilitar la selección se asignará un número a cada museo, de manera que el usuario elija por número. Los museos se pueden recuperar de la penúltima columna de la tabla de la página de wikipedia. Una vez elegido el museo, el programa mostrará una lista de todas las pinturas que cumplen ese requisito. De cada pintura se mostrará la información que aparece en las columnas: Título, Fecha, Dimensiones, y País. Así mismo, se creará una carpeta en el sistema de archivos, y se guardarán todas las imagenes de las pinturas que cumplen la condición de búsqueda sobre museo.
#
# __Nota: Para procesar la página html es obligatorio utilizar la libreria BeautifulSoup. No se pueden usar otras librerías no vistas en clase__

# %%
#Elige opcion
option = menu()

if int(option) == 1:
    buscarPorPais()
#else:
#    buscarPorMuseo()
# Out:
# MENÚ
# ----
# 1 - Buscar por país
# 2 - Buscar por museo
# ----
# Introduce elección: 1
#
# 1  -  España
# 2  -  Estados Unidos
# 3  -  Francia
# 4  -  Alemania
# 5  -  México
# 6  -  Italia
# 7  -  Suecia
# 8  -  Suiza
# 9  -  Brasil
# 10 -  Hungría
# 11 -  Reino Unido
# 12 -  Canadá
# 13 -  Irlanda
# 14 -  Węgry
# 15 -  Niemcy
# 16 -  Rusia
# 17 -  República Checa
# 18 -  Países Bajos
# 19 -  Catar
# Introduce elección: 1
# Asunción de la Virgen y San Íñigo
# h. 1763?[5]​
# 230 × 70 cm
# San Juan El Real (Calatayud)
# _____________________
# Consagración de San Luis Gonzaga como patrono de la juventud[6]​
# h. 1763?
# 127 x 88 cm
# Museo de Zaragoza (desde 1985) procedente de San Juan El Real de Calatayud (1763?-1767) y de la ermita de la Virgen de Jaraba (1767-1985)
# _____________________
# Aparición de la Virgen del Pilar a Santiago
# h. 1769
# 79 × 55 cm
# Colección privada (Aragón)
# _____________________
# Sagrada Familia con San Joaquín y Santa Ana ante el Eterno en gloria o  La triple generación
# h. 1769
# 79 × 55 cm
# Colección Marquesa de las Palmas (Jerez de la Frontera)
# _____________________
# Aníbal vencedor contempla por primera vez Italia desde los Alpes
# 1770
# 87 × 131,5 cm
# Fundación Selgas-Fagalde (Cudillero)
# _____________________
# Aníbal vencedor contempla por primera vez Italia desde los Alpes (boceto I)
# 1770
# 30,5 × 38,5 cm
# Museo de Zaragoza
# _____________________
# Aníbal vencedor contempla por primera vez Italia desde los Alpes (boceto II)
# 1770
# 31,1 × 40,6 cm
# Colecció
# _____________________
# Sacrificio a Pan
# 1771
# 32,5 × 24 cm
# Colección José Gudiol (Barcelona)
# _____________________
# Sacrificio a Vesta
# 1771
# 32,5 × 24 cm
# Colección Félix Palacios Remondo (Zaragoza)
# _____________________
# Venus y Adonis
# 1771
# 23 × 12 cm
# Museo de Zaragoza
# _____________________
# Éxtasis de San Antonio Abad
# 1771
# 47,2 × 38,8 cm
# Colección privada
# _____________________
# Éxtasis de San Antonio Abad
# 1780
# 67 × 46 cm
# Museo de Zaragoza
# _____________________
# La Virgen del Pilar
# h. 1771-1774
# 56 × 42 cm
# Museo Provincial, Zaragoza
# _____________________
# La adoración del nombre de Dios
# 1772
# 700 × 1.500 cm
# Basílica de Nuestra Señora del Pilar (Zaragoza)
# _____________________
# Santa Bárbara
# h. 1772
# 97,2 × 78,5 cm
# Museo del Prado (Madrid)
# _____________________
# Piedad (atribuida)
# 1774
# 83,5 x 58 cm
# colección privada (Barcelona)[7]​
# _____________________
# Pinturas de la Cartuja del Aula Dei
# 1774
# 306 × 790 cm (Nacimiento de la Virgen)
# Cartuja de Aula Dei (Zaragoza)
# _____________________
# San Ignacio de Loyola
# 1775-1780
# 85 × 57 cm
# Colección privada, Zaragoza
# _____________________
# El apóstol Santiago y sus discípulos adorando a la Virgen del Pilar
# 1775-80
# 107 × 80 cm
# colección privada
# _____________________
# Cristo crucificado
# 1780
# 255 × 154 cm
# Museo del Prado (Madrid)
# _____________________
# La Virgen en gloria y santos mártires(Detalle de San Valero)
# 1780
#
# Basílica de Nuestra Señora del Pilar (Zaragoza)
# _____________________
# Martín Zapater
# h. 1780
# 46,5 x 32 cm
# Colección privada
# _____________________
# La letra con sangre entra
# 1780 - 1785
# 19,7 x 38,7 cm
# Museo de Zaragoza
# _____________________
# Antonio Veyán y Monteagudo
# 1782
# 231 × 172,5 cm
# Museo de Huesca
# _____________________
# Mariano Ferrer y Aulet
# 1780-1783
# 83,9 × 63,4 cm
# Real Academia de Bellas Artes San Carlos
# _____________________
# Miguel de Múzquiz y Goyeneche, conde de Gausa
# 1783–1785
# 200 × 114 cm
# Banco de España
# _____________________
# Retrato de Camilo Goya
# 1783–1784
# 94 × 71 cm
# Museo Zuloaga
# _____________________
# Retrato de María Teresa de Vallabriga
# 1783
# 48 × 39,6 cm
# Prado
# _____________________
# Retrato del infante don Luis
# 1783
# 48,5 × 39,4 cm
# Colección duques de Sueca
# _____________________
# Retrato de Luis María de Borbón y Vallabriga, niño
# 1783
# 133 × 114,7 cm
# Museo de Zaragoza
# _____________________
# El conde de Floridablanca
# 1783
# 262 × 166 cm
# Banco de España (Madrid)
# _____________________
# El conde de Floridablanca
# 1783
# 196 × 161,5 cm
# Prado
# _____________________
# San Bernardino de Siena predicando ante Alfonso V de Aragón
# 1783
# 480 x 300 cm
# Iglesia de San Francisco el Grande (Madrid)
# _____________________
# Inmaculada Concepción
# 1783–1784
# 80 × 41 cm
# Prado
# _____________________
# Retrato de Ceán Bermúdez
# 1785
# 82 x 55 cm
# Colección particular
# _____________________
# Gaspar Melchor de Jovellanos
# 1780–1785
# 185 × 110 cm
# Museo Nacional de Escultura, depositado en Museo de Bellas Artes de Asturias
# _____________________
# Hércules y Ónfale
# 1784
# 81 × 64 cm
# Colec
# _____________________
# La duquesa de Osuna
# 1785
#
# Colección March (Palma de Mallorca)
# _____________________
# Pedro Téllez Girón, IX duque de Osuna
# 1785
# 118 × 82 cm
# Colec
# _____________________
# Asalto al coche
# 1786-1787
# 130 × 131 cm
# Colección privada (Madrid)
# _____________________
# La conducción de un sillar o La obra
# 1786-1787
# 169 x 127 cm
# Grupo Planeta Corporación
# _____________________
# El columpio
# 1786–1787
# 169 × 100 cm
# Colección privada (Madrid)
# _____________________
# La cucaña
# 1786–1787
# 169 × 88 cm
# Colección privada (Madrid)
# _____________________
# La caída
# 1786–1787
# 169 × 98 cm
# Colección privada (Madrid)
# _____________________
# Procesión rural
# 1786–1787
# 169 × 98 cm
# Colección privada (Madrid)
# _____________________
# Apartado de toros
# 1786–1787
# 165 × 285 cm
# Paradero
# _____________________
# Retrato de Francisco Bayeu
# 1786
# 112 × 84 cm
# Museo de Bellas Artes de Valencia
# _____________________
# Carlos III en traje de Corte
# 1786
# 194 × 110 cm
# Banco de España
# _____________________
# José de Toro y Zambrano
# 1786
# 112 × 68 cm
# Banco de España
# _____________________
# Miguel Fernández Durán, marqués de Tolosa
# 1786–1787
# 112 × 78 cm
# Banco de España
# _____________________
# Francisco Javier de Larrumbe
# 1787
# 113 × 77 cm
# Banco de España
# _____________________
# Carlos III en traje de cazador
# 1786-1788
# 210 × 127 cm
# Colección Argentaria, Banco Exterior de España (Madrid)
# _____________________
# Retrato del conde de Altamira
# 1787
# 112 × 78 cm
# Banco de España
# _____________________
# Sagrada Familia
# h. 1787
# 63,5 × 51,5 cm
# Prado
# _____________________
# Tobías y el ángel
# h. 1787
# 63,5 × 51,5 cm
# Prado
# _____________________
# Santa Ludgarda
# 1787
# 220 × 160 cm
# Real Monasterio de San Joaquín y Santa Ana (Valladolid)
# _____________________
# La muerte de San José o el Tránsito de San José
# 1787
# 220 × 152 cm
# Real Monasterio de San Joaquín y Santa Ana (Valladolid)
# _____________________
# Los santos Bernardo y Roberto
# 1787
# 220 × 160 cm
# Real Monasterio de San Joaquín y Santa Ana (Valladolid)
# _____________________
# San Francisco de Borja despidiéndose de su familia
# 1788
# 350 × 300 cm
# Catedral de Valencia (Valencia)
# _____________________
# San Francisco de Borja despidiéndose de su familia (boceto)
# 1788
# 38 × 29,3 cm
# Colección particular
# _____________________
# San Francisco de Borja y el moribundo impenitente
# 1788
# 350 × 300 cm
# Catedral de Valencia (Valencia)
# _____________________
# San Francisco de Borja y el moribundo impenitente  (boceto)
# 1788
# 38 × 29,3 cm
# Colección Marquesa Santa Cruz (Madrid)
# _____________________
# Sagrada Familia
# 1788 - 1790
# 203 x 148 cm
# Museo del Prado (Madrid)
# _____________________
# Los duques de Osuna y sus hijos o La familia del duque de Osuna
# 1788
# 225 x 171 cm
# Museo del Prado (Madrid)
# _____________________
# El Conde de Cabarrús
# 1788
# 210 × 127 cm
# Banco de España
# _____________________
# Carlos IV de rojo
# 1789
# 127 cm x 94 cm
# Museo del Prado (Madrid)
# _____________________
# María Luisa de Parma, reina de España
# 1789
# 127 × 94 cm
# Prado
# _____________________
# Maria Luisa de Parma con tontillo
# 1789
# 205 × 132 cm
# Prado
# _____________________
# Carlos IV en traje de Corte
# 1789
# 203 × 137 cm
# Prado
# _____________________
# Carlos IV
# 1789
# 137 × 110 cm
# Real Academia de la Historia (Madrid)
# _____________________
# Carlos IV
# 1790
# 152 × 110 cm
# Museo de Zaragoza
# _____________________
# Maria Luisa de Parma, reina de España
# 1789
# 152 × 110 cm
# Museo de Zaragoza
# _____________________
# Juan Martín de Goicoechea y Galarza
# 1789
# 84 × 65 cm
# Museo de Zaragoza
# _____________________
# Retrato de doña Tadea Arias de Enríquez
# h. 1790
# 190 × 106 cm
# Museo del Prado (Madrid)
# _____________________
# Antonio Aniceto de Porlier, marqués de Bajamar
# h. 1790
# 101 × 80 cm
# Colección privada
# _____________________
# María Jerónima Daoíz y Guendica, marquésa de Bajamar
# h. 1790
# 103,4 × 81,5 cm
# Colección privada
# _____________________
# Retrato del canónigo Ramón Pignatelli
# 1790–1791
# 79,5 × 62 cm
# Colección privada dquesa de Villahermosa (Madrid)
# _____________________
# Mi amigo Martín Zapater. Con el mayor trabajo te ha hecho el Retrato, Goya, 1790
# 1790
# 82,8 × 64,5 cm
# Museo de Arte de Ponce (Puerto Rico)
# _____________________
# Autorretrato en el taller
# 1790 – 1795
# 42 × 28 cm
# Real Academia de Bellas Artes de San Fernando (Madrid)
# _____________________
# El bordador Juan López de Robredo
# 1790–1800
# 107 × 81 cm
# Colección privada
# _____________________
# La Tirana
# 1790-1792
# 206 x 130 cm
# Real Academia de San Fernando (Madrid)
# _____________________
# Retrato de Juan Agustín Ceán Bermúdez
# 1792–1793
# 122 × 88 cm
# Colección privada
# _____________________
# Naufragio
# 1793
# 50 x 32 cm
# Colección Marqués de Oquendo (Madrid)
# _____________________
# Incendio, fuego de noche
# 1793
# 43 x 32 cm
# Colección José Varez (San Sebastián)
# _____________________
# Los cómicos ambulantes
# 1793
# 42 x 32 cm
# Museo del Prado (Madrid)
# _____________________
# Asalto de ladrones
# 1793 - 1794
# 42 x 31 cm
# Colección Castro Serna (Madrid)
# _____________________
# General Antonio Ricardos
# 1793–1794
# 84 × 112 cm
# Prado
# _____________________
# General Antonio Ricardos
# 1793–1794
# 81 × 110 cm
# Fundación Selgas-Fagalde (Cudillero)
# _____________________
# El general Ricardos, ante su cañón de batalla
# 1793–1794
# 225 × 110 cm
# Colección privada
# _____________________
# Retrato ecuestre de Manuel Godoy (boceto)
# 1794
# 55,2 × 44,5 cm
# Colección privada
# _____________________
# María del Rosario Fernández, La Tirana
# 1794
# 112 x 79 cm
# Colección privada
# _____________________
# Pedro Gil de Tejada
# 1794–1795
# 112 × 84 cm
# Colección privada
# _____________________
# Juan José de Arias Saavedra y Verdugo
# 1794–1795
# 82 × 55 cm
# Colec
# _____________________
# La parábola de los convidados a la boda
# 1796–1797
# 146 × 340 cm
# Oratorio Santa Cueva (Cádiz)
# _____________________
# La multiplicación de los panes y los peces
# 1796–1797
# 146 × 340 cm
# Oratorio Santa Cueva (Cádiz)
# _____________________
# La Santa Cena
# 1796–1797
# 147 × 344 cm
# Oratorio Santa Cueva (Cádiz)
# _____________________
# La Santa Cena (boceto)
# 1796–1797
# 25 × 42 cm
# Colec
# _____________________
# La Duquesa de Alba y la Beata
# 1795
# 30,7 x 25,4 cm
# Museo del Prado (Madrid)
# _____________________
# La Beata con dos niños
# 1795
# 31 × 25 cm
# Colección privada
# _____________________
# Retrato del pintor Francisco Bayeu
# 1795
# 112 x 84 cm
# Museo del Prado (Madrid)
# _____________________
# Valentín Bellvís de Moncada y Pizarro
# 1795
# 115 × 83 cm
# Fondo Cultural Villar Mir (Madrid)
# _____________________
# Un garrochista
# 1795
# 57 × 47 cm
# Museo del Prado (Madrid)
# _____________________
# José Álvarez de Toledo, duque de Alba
# 1795
# 195 × 120 cm
# Museo del Prado (Madrid)
# _____________________
# La marquesa viuda de Villafranca
# 1795
# 87 × 72 cm
# Museo del Prado (Madrid)
# _____________________
# La Duquesa de Alba
# 1795
# 194 x 130 cm
# Colección Alba (Madrid)
# _____________________
# Goya, a su amigo Martín Zapater
# 1797
# 87 × 64 cm
# Museo de Bellas Artes (Bilbao)
# _____________________
# San Agustín
# 1796–1799
# 190 × 115 cm
# Colección privada
# _____________________
# San Gregorio
# h. 1797
# 188 x 113 cm
# Museo Romántico (Madrid)
# _____________________
# El aquelarre
# 1797-1798
# 43 x 30 cm
# Fundación Lázaro Galdiano (Madrid)
# _____________________
# El conjuro o Escena de brujas
# 1797–1798
# 43,5 × 30,5 cm
# Fundación Lázaro Galdiano (Madrid)
# _____________________
# Vuelo de brujas
# 1797–1798
# 43,5 × 30,5 cm
# Museo del Prado (Madrid)
# _____________________
# La maja desnuda
# h. 1797-1800
# 97 × 190 cm
# Museo del Prado (Madrid)
# _____________________
# Retrato de Asensio Julià
# h. 1798
# 55 × 41 cm
# Museo Thyssen-Bornemisza
# _____________________
# Retrato de Gaspar Melchor de Jovellanos
# 1798
# 205 × 133 cm
# Museo del Prado (Madrid)
# _____________________
# San Luis Gonzaga meditando
# 1798–1800
# 261 × 160 cm
# Museo de Zaragoza
# _____________________
# José de Urrutia y de las Casas
# h. 1798
# 199 x 133 cm
# Museo del Prado (Madrid)
# _____________________
# El prendimiento de Cristo
# ok. 1798
# 300 × 200 cm
# Catedral de Toledo
# _____________________
# El prendimiento de Cristo (boceto)
# ok. 1798
# 40 × 23 cm
# Prado
# _____________________
# Mariano Luis de Urquijo
# 1797–1798
# 128 × 97 cm
# Real Academia de la Historia
# _____________________
# Milagro de san Antonio de Padua
# 1798
#
# San Antonio de la Florida (Madrid)
# _____________________
# Alegoría del Amor o Cupido y Psique
# 1798c1805
# 200 x 156 cm
# MNAC (Barcelona)  Legado Cambó
# _____________________
# San Hermenegildo en la prisión
# 1799
# 23 × 30 cm
# Museo Lázaro Galdiano
# _____________________
# Leandro Fernández de Moratín
# 1799
# 73 x 56 cm
# Real Academia de San Fernando (Madrid)
# _____________________
# Carlos IV vestido de cazador
# 1799
# 336 × 282 cm
# Museo del Prado (Madrid)
# _____________________
# La reina María Luisa a caballo
# 1799
# 338 × 282 cm
# Museo del Prado (Madrid)
# _____________________
# Carlos IV a caballo
# 1800
# 336 × 282 cm
# Museo del Prado (Madrid)
# _____________________
# Carlos IV en uniforme de coronel de la Guardia de Corps
# 1799–1800
# 202 × 126 cm
# Palacio Real de Madrid
# _____________________
# María Luisa en traje de corte
# 1799–1800
# 210 × 130 cm
# Palacio Real de Madrid
# _____________________
# La infanta María Josefa
# 1800
# 72 × 59 cm
# Prado
# _____________________
# El infante Carlos María Isidro
# 1800
# 74 × 60 cm
# Prado
# _____________________
# El infante Francisco de Paula
# 1800
# 74 × 60
# Prado
# _____________________
# El infante Antonio Pascual
# 1800
# cm 72,5 × 59,3 cm
# Prado
# _____________________
# Luis de Etruria
# 1800
# 72,5 × 59,4 cm
# Prado
# _____________________
# La familia de Carlos IV
# 1800
# 280 × 336 cm
# Museo del Prado (Madrid)
# _____________________
# Arzobispo Joaquín Company
# h. 1800
# 199 × 102,5 cm
# Museo Alma Mater (Zaragoza)
# _____________________
# Arzobispo Joaquín Company (boceto)
# h. 1800
# 31 × 44 cm
# Prado
# _____________________
# La condesa de Chinchón
# 1800
# 216 x 144 cm
# Museo del Prado (Madrid)
# _____________________
# Retrato de la reina María Luisa de Parma
# 1800
# 209 × 125 cm
# Museo del Prado (Madrid)
# _____________________
# Manuel Godoy, Príncipe de la Paz
# 1801
# 180 × 267
# Real Academia de San Fernando
# _____________________
# Retrato de la condesa de Haro
# 1802
# 59 × 36 cm
# Colección privada
# _____________________
# La maja vestida
# h. 1802-1805
# 95 × 188 cm
# Museo del Prado (Madrid)
# _____________________
# El conde de Fernán Núñez
# 1803
# 211 × 137 cm
# Colección Duques de Fernán Núñez (Madrid)
# _____________________
# La condesa de Fernán Núñez
# 1803
# 211 × 137 cm
# Colección Duques de Fernán Núñez (Madrid)
# _____________________
# Joaquina Candado
# 1802
# 169 × 118,36 cm
# Real Academia de Bellas Artes San Carlos
# _____________________
# Marquesa de Lazán
# h. 1804
# 193 × 115 cm
# Palacio de Liria (Madrid)
# _____________________
# Retrato de Juan de Villanueva
# h. 1805
# 90 × 67 cm
# Real Academia de San Fernando
# _____________________
# Marqués de San Adrián
# 1804
# 209 × 127 cm
# Museo de Navarra
# _____________________
# José de Vargas Ponce
# 1805
# 104 × 82 cm
# Real Academia de la Historia (Madrid)
# _____________________
# Alegoría de la Industria
# 1804-1806
# 227 cm diámetro
# Museo del Prado (Madrid)
# _____________________
# Alegoría del Comercio
# 1804–1806
# 227 cm ⌀
# Prado
# _____________________
# Alegoría de la Agricultura
# 1804–1806
# 227 cm ⌀
# Prado
# _____________________
# Retrato de Félix de Azara
# 1805
# 212 × 124 cm
# Colección IberCaja (Zaragoza)
# _____________________
# Retrato de la Marquesa de Santa Cruz
# 1805
# 125 x 208 cm
# Museo del Prado (Madrid)
# _____________________
# Leonora Antonia Valdés de Barruso
# 1805
# 104 × 83 cm
# Colec
# _____________________
# María Vicenta Barruso Valdés
# 1805
# 104 × 83 cm
# Colec
# _____________________
# Francisco Javier Goya y Bayeu
# 1805
# 192 × 115 cm
# Colec
# _____________________
# Gumersinda Goicoechea
# 1805
# 192 × 115 cm
# Colec
# _____________________
# Francisco Javier Goya y Bayeu
# 1805
# 8 cm ⌀
# Museo de Zaragoza
# _____________________
# Gumersinda Goicoechea
# 1805
# 8 cm ⌀
# Museo de Zaragoza
# _____________________
# Juana Galarza de Goicoechea
# 1805
# 8 cm ⌀
# Prado
# _____________________
# Manuela Goicoechea y Galarza
# 1805
# 8 cm ⌀
# Prado
# _____________________
# Isidoro Máiquez
# 1807
# 72 x 59 cm
# Museo del Prado (Madrid)
# _____________________
# Pantaleón Pérez de Nenin
# 1808 o 1814–1815
# 206 × 124,7 cm
# Colección BBVA (Madrid)
# _____________________
# Retrato ecuestre de Fernando VII
# 1808
# 285 × 205 cm
# Real Academia de San Fernando (Madrid)
# _____________________
# El coloso
# 1808-1812
# 116 × 105 cm
# Museo del Prado (Madrid)
# _____________________
# El Lazarillo de Tormes
# 1808-1812
# 80 × 65 cm
# Colección Marañón (Madrid)
# _____________________
# Confesión en la cárcel/Locos en el manicomio
# 1808-1812
# 40 × 65 cm
# Museo del Monasterio de Guadalupe (Guadalupe)
# _____________________
# Majas y celestina en el balcón
# 1808-1812
# 166 x 108 cm
# Colección B. March (Palma de Mallorca)
# _____________________
# Retrato de la marquesa de Montehermoso
# 1808-1812[8]​ (h. 1810[9]​)
# 170 x 103 cm
# Colec
# _____________________
# Manuel Silvela
# 1809-1812
# 95 × 68 cm
# Museo del Prado (Madrid)
# _____________________
# Retrato de Mariano Goya
# 1812-1814
# 59 x 47 cm
# Colección Duque de Alburquerque (Madrid)
# _____________________
# El entierro de la sardina
# 1812-1819
# 82,5 × 62 cm
# Real Academia de Bellas Artes de San Fernando (Madrid)
# _____________________
# Auto de fe de la Inquisición
# 1812-1819
# 46 × 73 cm
# Real Academia de Bellas Artes de San Fernando (Madrid)
# _____________________
# Casa de locos
# 1812-1819
# 45 x 72 cm
# Real Academia de Bellas Artes de San Fernando (Madrid)
# _____________________
# Procesión de disciplinantes
# 1812-1819
# 46 × 73 cm
# Real Academia de Bellas Artes de San Fernando (Madrid)
# _____________________
# Corrida de toros en un pueblo
# 1812-1814
# 45 × 72 cm
# Real Academia de Bellas Artes de San Fernando (Madrid)
# _____________________
# El 2 de mayo de 1808 en Madrid:la carga de los mamelucos
# 1814
# 280 × 336 cm
# Museo del Prado (Madrid)
# _____________________
# Los fusilamientos del 3 de mayo en la montaña del Príncipe Pío
# 1814
# 268 × 347 cm
# Museo del Prado (Madrid)
# _____________________
# Juan Martín Díaz, el Empecinado
# h. 1814-1815
# 84 × 65 cm
# Colec
# _____________________
# El duque de San Carlos
# 1815
# 237 × 153 cm
# Museo de Zaragoza (Zaragoza)
# _____________________
# Manuel Quijano
# 1815
# 86,8 × 56,5 cm
# Museu Nacional d'Art de Catalunya
# _____________________
# José Luis Munárriz
# 1815
# 85 × 64 cm
# Real Academia de Bellas Artes de San Fernando (Madrid)
# _____________________
# Autorretrato
# 1815
# 46 × 35 cm
# Museo del Prado (Madrid)
# _____________________
# Autorretrato
# h. 1815
# 51 × 46 cm
# Real Academia de San Fernando (Madrid)
# _____________________
# Fray Juan Fernández de Rojas
# 1815–1816
# 75 × 54 cm
# Real Academia de la Historia (Madrid)
# _____________________
# Santa Isabel de Portugal curando a una enferma (boceto)
# 1816
# 33 × 32 cm
# Museo Lázaro Galdiano (Madrid)
# _____________________
# Santa Isabel de Portugal curando a una enferma
# 1816
# 169 × 129 cm
# Palacio Real de Madrid
# _____________________
# La duquesa de Abrantes
# 1816
# 92 × 70 cm
# Prado
# _____________________
# Tío Paquete
# 1819–1820
# 39 × 31 cm
# Museo Thyssen-Bornemisza (Madrid)
# _____________________
# Santa Justa y Santa Rufina
# 1819
# 309 × 177 cm
# Catedral de Santa María de la Sede de Sevilla
# _____________________
# Cristo en el huerto de los olivos
# 1819
# 47 × 35 cm
# Escuelas Pías de San Antón (Madrid)
# _____________________
# La última comunión de San José de Calasanz
# 1819
# 250 × 180 cm
# Museo de la Residencia Calasanz (Madrid)
# _____________________
# Átropos o Las Parcas
# 1819-1823
# 123 × 266 cm
# Museo del Prado (Madrid)
# _____________________
# El aquelarre o  El gran cabrón
# 1819-1823
# 140 × 438 cm
# Museo del Prado (Madrid)
# _____________________
# Duelo a garrotazos
# 1819-1823
# 123 × 266 cm
# Museo del Prado (Madrid)
# _____________________
# Saturno devorando a un hijo
# 1819-1823
# 146 × 83 cm
# Museo del Prado (Madrid)
# _____________________
# Dos viejos comiendo sopa
# 1819-1823
# 49,3 × 83,4 cm
# Museo del Prado (Madrid)
# _____________________
# Visión fantástica o Asmodea
# 1819-1823
# 123 × 265 cm
# Museo del Prado (Madrid)
# _____________________
# La romería de San Isidro
# 1819-1823
# 140 × 438 cm
# Museo del Prado (Madrid)
# _____________________
# Perro semihundido
# 1819-1823
# 131,5 × 79,3 cm
# Museo del Prado (Madrid)
# _____________________
# Dos viejos, Dos frailes o  Un viejo y un fraile
# 1819-1823
# 123 × 265 cm
# Colección particular (Salamanca)
# _____________________
# Hombres leyendo
# 1819-1823
# 126 × 66 cm
# Museo del Prado (Madrid)
# _____________________
# Judith y Holofernes
# 1819-1823
# 143,5 × 81,4 cm
# Museo del Prado (Madrid)
# _____________________
# Dos mujeres y un hombre o Dos mujeres riéndose de un hombre
# 1819-1823
# 125 × 65,5 cm
# Museo del Prado (Madrid)
# _____________________
# Peregrinación a la fuente de San Isidro o Procesión del Santo Oficio
# 1819-1823
# 123 × 266 cm
# Museo del Prado (Madrid)
# _____________________
# Una manola: doña Leocadia Zorrilla
# 1819-1823
# 147,5 × 129,4 cm
# Museo del Prado (Madrid)
# _____________________
# Retrato de dama con mantilla
# 1823–1824
# 61 × 51 cm
# Museo de Zaragoza
# _____________________
# El padre José de La Canal
# 1808–1824
# 74 × 65 cm
# Museo Lázaro Galdiano (Madrid)
# _____________________
# Don José Duaso y Larte
# 1824
# 74,5 x 59 cm
# Museo de Bellas Artes de Sevilla (Sevilla)
# _____________________
# Leandro Fernández de Moratín
# 1824
# 60 x 49,5 cm
# Museo de Bellas Artes de Bilbao
# _____________________
# La lechera de Burdeos
# h. 1825-1827
# 74 x 68 cm
# Museo del Prado (Madrid)
# _____________________
# Juan Bautista de Muguiro
# 1827
# 101 x 89 cm
# Museo del Prado (Madrid)
# _____________________
# ¿En qué carpeta guardas las imagenes? 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-d1f3e1573da8> in <module>()
#       3
#       4 if int(option) == 1:
# ----> 5     buscarPorPais()
#       6 #else:
#       7 #    buscarPorMuseo()
#
# <ipython-input-6-7f04f35fc193> in buscarPorPais()
#      37
#      38     #Guardo imagenes en carpeta
# ---> 39     guardaCarpeta(lista[int(elemento) - 1], etiquetas)
#
# <ipython-input-32-d5a115c88e19> in guardaCarpeta(pais, etiquetas)
#      11     os.chdir(path)
#      12
# ---> 13     etiquetas.find(['href', 'a'])
#      14
#      15     i = 0
#
# /anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
def menu():
    
    print("MENÚ")
    print("----")
    print("1 - Buscar por país")
    print("2 - Buscar por museo")
    print("----")
    inputCorrecto = False
    
    while not inputCorrecto:
        elemento = input("Introduce elección: ")
        try:
            if int(elemento) > 0 and int(elemento) < 2:
                inputCorrecto = True
            else:
                print("\nError. Introduce una opción posible.")
        except:
            print("\nError. Introduce un numero correcto.") # Necesitamos numeros
    return elemento

# %%
#Busqueda por pais
def buscarPorPais():
    import urllib
    import requests
    from bs4 import BeautifulSoup
    url = "https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Goya"
    r = requests.get(url)
    html = r.text

    soup = BeautifulSoup(html, 'html.parser')
    etiquetas = soup("tr")
    print()
    lista = listaPaises(etiquetas)

    # Sacamos por pantalla los paises
    i = 1
    for pais in lista:
        if i > 9:
            print(i , "- ", pais)
        else:
            print(i , " - ", pais)
        i = i + 1
        
    #Elige un pais
    inputCorrecto = False
    while not inputCorrecto:
        elemento = input("Introduce elección: ")
        try:
            if int(elemento) > 0 and int(elemento) < len(lista):
                inputCorrecto = True
            else:
                print("\nError. Introduce una opción posible.")
        except:
            print("\nError. Introduce un numero correcto.") # Necesitamos numeros
            
    pinturas = cuadrosPais(lista[int(elemento) - 1], etiquetas)
    
    #Guardo imagenes en carpeta
    guardaCarpeta(lista[int(elemento) - 1], etiquetas)

# %%
def listaPaises(etiquetas):
    lista = []
    i = 0
    for etiqueta in etiquetas: 
        if i > 0:
            s = 0
            for item in etiqueta:
                if s == 11:
                    newPais = item.text.split()

                    if len(newPais) > 0:
                        aux = newPais[0]
                        if newPais[0] == "República": #Es el único que no está duplicado
                            aux = aux  + " " + newPais[1]
                        if len(newPais) > 2:
                            aux = ""
                            j = 0
                            for member in newPais:
                                if j < len(newPais) / 2:
                                    aux = aux + member + " "
                                j = j + 1
                        if aux not in lista:   
                            lista.append(aux)
                s = s + 1
        i = i + 1
    return lista

# %%
def cuadrosPais(pais, etiquetas):
    #Se mostrará la información que aparece en las columnas: Título, Fecha, Dimensiones, y Museo
    lista = []
    i = 0
    for etiqueta in etiquetas:
        if i > 0:
            s = 0
            for item in etiqueta:
                if s == 11:
                    newPais = item.text.split()
                    if len(newPais) > 0:
                        aux = newPais[0]
                    if(aux == pais):
                        lista.append(etiqueta)
                s = s + 1
        i = i + 1
    
    for etiqueta in lista:
        a = etiqueta.text[: len(etiqueta.text) - 2 * len(pais) - 2].strip()
        print(a)
        print("_____________________")
        
    return True

# %%
import os
def guardaCarpeta(pais, etiquetas):

    path = input("¿En qué carpeta guardas las imagenes? ")
    if not os.path.exists(path):
        try:
            os.makedirs(path)
        except OSError:
            print("Error creatng the folder!")

    os.chdir(path)
    
    #Guardar imagenes

# %% [raw]
# # Normas de entrega
#
# * Fecha tope de entrega: 28/10/2018
# * La entrega se realizará subiendo al campus virtual un notebook de Jupyter con la solución. El archivo tendrá como nombre WebScraping_GrupoX donde X será el número de grupo correspondiente.
