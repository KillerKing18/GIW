# %% [markdown]
# ### Práctica de Formatos de datos: CSV y JSON

# %% [markdown]
# #### Ejercicio 1[5 puntos]
# Considerar el archivo __Agenda.csv__ que contiene una relación de actividades de carácter cultural y de ocio, que se van a celebrar en los próximos 100 días y que se están celebrando en centros Municipales.
#
# Se pide crear un programa que permita realizar búsquedas sobre los datos incluidos en el documento. Para ello, se le preguntarán al usuario diversas preguntas que configurarán la consulta a realizar:
# * Primera pregunta. Distrito. Debe listar el conjunto de distritos que contiene el documento __[Campo Distrito]__, y el usuario deberá elegir uno de ellos. Se puede asignar un número o letra a cada distrito de manera que el usuario introduzca únicamente el número o letra seleccionado.
#
# * Segunda pregunta. Actividad. Debe listar el conjunto de tipos de actividades __[Campo Tipo]__, y el usuario deberá elegir uno de ellos. Se puede asignar un número o letra a cada tipo de actividad de manera que el usuario introduzca únicamente el número o letra seleccionado. Observar que para mostrar el tipo de actividad, hay que tratar el valor que aparece en el campo, de manera que se elimine la parte inicial de la cadena "/contenido/actividades/"
#
# * Tercera pregunta. Audiencia. Debe listar el conjunto de tipos de audiencia __[Campo Audiencia]__, y el usuario deberá elegir uno de ellos. Se puede asignar un número o letra a cada tipo de audiencia de manera que el usuario introduzca únicamente el número o letra seleccionado. Observar que para mostrar el tipo de audiencia, hay que tratar el valor que aparece en el campo, de manera que se elimine las apariciones de "/usuario/". Así mismo, hay casos en los que no existe una audiencia. En esos casos, cuando se realice una búsqueda, no será un campo de restricción, es decir que podrá aparecer como respuesta en las consultas si cumple los dos primeros criterios.
#
# * Cuarta pregunta. Horario. Se listará un conjunto de horarios en forma de intervalos de una hora. Por ejemplo 00:00-01:00,01:00-02:00..., 23:00-23:59. Se puede asignar un número o letra a cada tipo de audiencia de manera que el usuario introduzca únicamente el número o letra seleccionado. Estos intervalos no se obtienen del documento.
#
# Como resultado el programa deberá mostrar por pantalla información de las actividades que cumplen las respuestas introducidas. Concretamente:
#
# * Si no existe ningún evento con las condiciones indicadas entonces se mostrará el mensaje: "No existe ningún evento con las condiciones indicadas".
#
# * Si existen eventos que coinciden con las condiciones dadas, entonces por cada evento se debe mostrar por pantalla.
#
#   1. Título.
#
#   2. Fecha de inicio-Fecha de finalización.
#
#   3. Días de la semana.
#
#   4. Días excluidos.
#
#   5. Hora.
#
#   6. Descripción.
#
#   7. Nombre de instalación.
#
#   8. Tipo de actividad.
#
#   9. Audiencia.
#
# * Generar un documento salida.csv con los resultados obtenidos.

# %%
def displayEvent(evento):
    i = 0
    for item in evento:
        if len(item) == 0:
             print(str(i) + "\t--Indefinido--")
        else:
            print(str(i) + "\t" + item)
        i = i + 1

# %%
def displayAndList(lista, miembros, restriccion):
    i = 1
    for item in miembros:
        if restriccion == 0: #Distrito u horas
            if len(item) == 0:
                print(str(i) + "\t--Indefinido--")
            else:
                print(str(i) + "\t" + item)
        elif restriccion == 1: #Tipo de actividad
            if len(item) == 0:
                print(str(i) + "\t--Indefinido--")
            else:
                print(str(i) + "\t" + item[23:])
        elif restriccion == 2: #Tipo de audiencia
            if len(item) == 0:
                print(str(i) + "\t--Indefinido--")
            else:
                print(str(i) + "\t" + item[9:])
        #elif restriccion == 3: #Longitud y latitud
            
        lista.append(item)
        i = i + 1

# %%
def checkCorrectness(caso):
    inputCorrecto = False
    while not inputCorrecto:
        elemento = input('\nIntroduce el numero del '+ caso + ":")
        try:
            elemento = lista[int(elemento) - 1]
            inputCorrecto = True
        except:
            print("\nError. Introduce un numero correcto.")
    return elemento;

# %% [markdown]
# Para leer los archivos usa un código como el siguiente:

# %%
#TODO intervalos, audiencias separadas por comas, audiencia inexistente, distrito inexistentes, tipo de actividad inexistente
import csv
csvarchivo = open('Agenda.csv',encoding="utf8",errors='ignore')
entrada = csv.reader(csvarchivo, delimiter=";")


#PRIMERO LEEMOS EL ARCHIVO Y ALMACENAMOS LOS DATOS EN UNA ESTRUCTURA DE DICCIONARIOS
distritos = {}
i = 0
for linea in entrada:
    #print("Linea " + str(i + 1) + ":")
    if i != 0: # Omitir primera linea
        if distritos.get(linea[20]) == None:
            #print("No existe un distrito llamado " + str(linea[20]) + ". Creándolo...")
            listaCampos = []
            listaCampos.append(linea[1])
            listaCampos.append(linea[7] + "-" + linea[8])
            listaCampos.append(linea[5])
            listaCampos.append(linea[6])
            listaCampos.append(linea[9])   
            listaCampos.append(linea[10])
            listaCampos.append(linea[15])
            listaCampos.append(linea[21])
            listaCampos.append(linea[22])
            listaActividades = []
            listaActividades.append(listaCampos)
            audienciasString = linea[22].split(",")
            audiencias = {}
            horarios = {}
            for aud in audienciasString:            
                horarios[linea[9]] = listaActividades
                audiencias[aud] = horarios
            tipoActividad = {}
            tipoActividad[linea[21]] = audiencias
            distritos[linea[20]] = tipoActividad
        else:
            #print("Existe el distrito llamado " + str(linea[20]) + ". Accediendo...")
            if distritos[linea[20]].get(linea[21]) == None:
                #print("No existe un tipo de actividad " + str(linea[21][23:]) + " para el distrito " + str(linea[20]) + ". Creándolo...")
                listaCampos = []
                listaCampos.append(linea[1])
                listaCampos.append(linea[7] + "-" + linea[8])
                listaCampos.append(linea[5])
                listaCampos.append(linea[6])
                listaCampos.append(linea[9])   
                listaCampos.append(linea[10])
                listaCampos.append(linea[15])
                listaCampos.append(linea[21])
                listaCampos.append(linea[22])
                listaActividades = []
                listaActividades.append(listaCampos)
                audienciasString = linea[22].split(",")
                audiencias = {}
                horarios = {}
                for aud in audienciasString:            
                    horarios[linea[9]] = listaActividades
                    audiencias[aud] = horarios
                distritos[linea[20]][linea[21]] = audiencias
            else:
                #print("Existe el tipo de actividad " + str(linea[21][23:]) + " para el distrito " + str(linea[20]) + ". Accediendo...")
                listaCampos = []
                listaCampos.append(linea[1])
                listaCampos.append(linea[7] + "-" + linea[8])
                listaCampos.append(linea[5])
                listaCampos.append(linea[6])
                listaCampos.append(linea[9])   
                listaCampos.append(linea[10])
                listaCampos.append(linea[15])
                listaCampos.append(linea[21])
                listaCampos.append(linea[22])
                audienciasString = linea[22].split(",")
                for aud in audienciasString:
                    if distritos[linea[20]][linea[21]].get(aud) == None:
                        #print("No existe el tipo de audiencia " + aud + " para el tipo de actividad " + str(linea[21][23:]) + " para el distrito " + str(linea[20]) + ". Creándolo...")
                        listaActividades = []
                        listaActividades.append(listaCampos)
                        horarios = {}
                        horarios[linea[9]] = listaActividades
                        distritos[linea[20]][linea[21]][aud] = horarios
                    else:
                        #print("Existe el tipo de audiencia " + aud + " para el tipo de actividad " + str(linea[21][23:]) + " para el distrito " + str(linea[20]) + ". Añadiendo nuevo horario...")
                        
                        if distritos[linea[20]][linea[21]][aud].get(linea[9]) == None:
                        # No existe el horario
                            listaActividades = []
                            listaActividades.append(listaCampos)
                            distritos[linea[20]][linea[21]][aud][linea[9]] = listaActividades
                        else:
                        # Existe el horario. Añadir la actividad a la lista de actividades a esa misma hora
                            distritos[linea[20]][linea[21]][aud][linea[9]].append(listaCampos)
    i = i + 1

print("Distritos almacenados:\n")

lista = []
displayAndList(lista, distritos.keys(), 0) #Enseña las posibilidades y las guarda en una lista

distrito = checkCorrectness("distrito"); #Pide el num hasta que sea un formato correcto

print("\nTipos de actividades almacenadas para el distrito " + distrito + ":\n")

lista = []
displayAndList(lista,distritos[distrito].keys(), 1) #Enseña las posibilidades y las guarda en una lista

actividad = checkCorrectness("tipo de actividad")

print("\nTipos de audiencia para el tipo de actividad " + actividad[23:] + " para el distrito " + distrito + ".\n")

lista = []
displayAndList(lista,distritos[distrito][actividad].keys(), 2) #Enseña las posibilidades y las guarda en una lista

audiencia = checkCorrectness("tipo de audiencia")

print("\nEstos son los horarios para el tipo de audiencia " + audiencia[9:] 
      + " para el tipo de actividad " + actividad[23:] + " para el distrito " + distrito + ":\n")

lista = []
displayAndList(lista,distritos[distrito][actividad][audiencia].keys(), 0) #Enseña las posibilidades y las guarda en una lista

hora = checkCorrectness("horario")
lista = []
for item in distritos[distrito][actividad][audiencia][hora]:
    displayAndList(lista, item, 0)

#ejercicioTres(distritos, distrito, actividad, audiencia)
# Out:
# Distritos almacenados:
#
# 1	HORTALEZA
# 2	CIUDAD LINEAL
# 3	VILLAVERDE
# 4	CENTRO
# 5	SAN BLAS-CANILLEJAS
# 6	BARAJAS
# 7	MORATALAZ
# 8	SALAMANCA
# 9	LATINA
# 10	VILLA DE VALLECAS
# 11	TETUAN
# 12	USERA
# 13	CHAMARTIN
# 14	PUENTE DE VALLECAS
# 15	VICALVARO
# 16	CHAMBERI
# 17	ARGANZUELA
# 18	CARABANCHEL
# 19	RETIRO
# 20	--Indefinido--
# 21	FUENCARRAL-EL PARDO
# 22	MONCLOA-ARAVACA
#
# Introduce el numero del distrito:5
#
# Tipos de actividades almacenadas para el distrito SAN BLAS-CANILLEJAS:
#
# 1	CuentacuentosTiteresMarionetas
# 2	CineActividadesAudiovisuales
# 3	RecitalesPresentacionesActosLiterarios
# 4	ConferenciasColoquios/Literatura
# 5	Exposiciones
# 6	CursosTalleres
# 7	TeatroPerformance
# 8	ConferenciasColoquios
# 9	Musica
# 10	DanzaBaile
# 11	CineActividadesAudiovisuales/CineFiccion
# 12	CineActividadesAudiovisuales/CineDocumental
#
# Introduce el numero del tipo de actividad:1
#
# Tipos de audiencia para el tipo de actividad CuentacuentosTiteresMarionetas para el distrito SAN BLAS-CANILLEJAS.
#
# 1	Niños
# 2	Familias
#
# Introduce el numero del tipo de audiencia:1
#
# Estos son los horarios para el tipo de audiencia Niños para el tipo de actividad CuentacuentosTiteresMarionetas para el distrito SAN BLAS-CANILLEJAS:
#
# 1	17:30
# 2	18:00
# 3	00:00
#
# Introduce el numero del horario:2
# 1	Animalitis por Roberto Mezquita
# 2	2018-11-07 00:00:00.0-2018-11-07 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Animalitis: dícese de la enfermedad que nos lleva a contar y escuchar cuentos de animales sin parar.  Los cuentos de animales están entre los preferidos por niñas y niños, pues resultan sugerentes, misteriosos, cercanos, fascinantes e inagotables. Y por supuesto, permiten acercarse disimulada y certeramente a las vivencias y problemas cotidianos de los humanos más pequeños y también de los más grandes. Y eso, siempre gusta.   La chispeante presencia del acordeón acabará por redondear la propuesta y nos permitirá además cantar y bailar todo aquello que venga a cuento.  De 4 a 9 años.
# 7	Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	Animalitis por Roberto Mezquita
# 2	2018-11-07 00:00:00.0-2018-11-07 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Animalitis: dícese de la enfermedad que nos lleva a contar y escuchar cuentos de animales sin parar.  Los cuentos de animales están entre los preferidos por niñas y niños, pues resultan sugerentes, misteriosos, cercanos, fascinantes e inagotables. Y por supuesto, permiten acercarse disimulada y certeramente a las vivencias y problemas cotidianos de los humanos más pequeños y también de los más grandes. Y eso, siempre gusta.   La chispeante presencia del acordeón acabará por redondear la propuesta y nos permitirá además cantar y bailar todo aquello que venga a cuento.  De 4 a 9 años.
# 7	Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	Cocinando cuentos. Exquisito menú de cuentos con Primigenius
# 2	2018-10-03 00:00:00.0-2018-10-03 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Leyenda cocinero del país de los cuentos. Llega a librerías, bibliotecas y demás cocinas con el deseo de guisar las más suculentas historias. Un gorro de cocinero, una cuchara que hace música, una cacerola de la que salen poemas, adivinanzas, trabalenguas y la maleta Enriqueta que guarda los secretos de los cuentos.  Los mejores cuentos, como los buenos guisos siempre salen a fuego lento.    El espectáculo es en si mismo un homenaje a la riqueza del idioma castellano. Está construido con cuentos, cantos, rimas, retahílas, adivinanzas, trabalenguas, colmos, tantanes, leyendas y patrañas principalmente de España, pero enriquecidas jugosamente por la experiencia vivida en los países latinoamericanos en nuestras giras.  Su elemento principal es el folclore: Cuentos de tradición y Cantos populares.  De 4 a 7 años.
# 7	Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	Cocinando cuentos. Exquisito menú de cuentos con Primigenius
# 2	2018-10-03 00:00:00.0-2018-10-03 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Leyenda cocinero del país de los cuentos. Llega a librerías, bibliotecas y demás cocinas con el deseo de guisar las más suculentas historias. Un gorro de cocinero, una cuchara que hace música, una cacerola de la que salen poemas, adivinanzas, trabalenguas y la maleta Enriqueta que guarda los secretos de los cuentos.  Los mejores cuentos, como los buenos guisos siempre salen a fuego lento.    El espectáculo es en si mismo un homenaje a la riqueza del idioma castellano. Está construido con cuentos, cantos, rimas, retahílas, adivinanzas, trabalenguas, colmos, tantanes, leyendas y patrañas principalmente de España, pero enriquecidas jugosamente por la experiencia vivida en los países latinoamericanos en nuestras giras.  Su elemento principal es el folclore: Cuentos de tradición y Cantos populares.  De 4 a 7 años.
# 7	Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	Cocinando cuentos. Exquisito menú de cuentos por Primigenius
# 2	2018-10-04 00:00:00.0-2018-10-04 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Leyenda cocinero del país de los cuentos. Llega a las  librerías, bibliotecas y demás cocinas con el deseo de guisar las más suculentas historias. Un gorro de cocinero, una cuchara que hace música, una cacerola de la que salen poemas, adivinanzas, trabalenguas y la maleta Enriqueta que guarda los secretos de los cuentos.  Los mejores cuentos, como los buenos guisos siempre salen a fuego lento.    El espectáculo es en si mismo un homenaje a la riqueza del idioma castellano. Está  construido con cuentos, cantos, rimas, retahílas, adivinanzas, trabalenguas, colmos, tantanes, leyendas y patrañas  principalmente de España, pero enriquecidas jugosamente por la experiencia vivida en los países latinoamericanos en nuestras giras.  Su elemento principal es el folclore: Cuentos de tradición y Cantos populares.  De 4 a 7 años.
# 7	Biblioteca Pública Municipal Canillejas (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños
# 1	La granja de los cuentos con Félix Jamacuco
# 2	2018-10-24 00:00:00.0-2018-10-24 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Dentro de la imaginería infantil ?el lobo? es un personaje querido, a la vez que temido. Siempre levanta sentimientos encontrados y siempre suscita curiosidad, pues es bien sabido que en todo relato que aparece uno o muchos lobos, será un relato que no nos dejará indiferentes.  Basándonos en la canción popular  ¡Me visto y te como!   y en el cuento popular  Sopa de piedra,  hemos creado un espectáculo de cuenta cuentos donde el humor, el juego, el ingenio del protagonista, la simpatía y la curiosidad y la buena voluntad del resto de los personajes crean un ambiente desenfadado y divertido.  Combinamos el simbolismo del lobo de los cuentos clásicos (astuto, mentiroso, pendenciero?) con el simbolismo del lobo de los cuentos modernos (bonachón, incomprendido, amigo de todo el mundo?) para crear una única historia y un lobo con múltiples personalidades.  De 3 a 8 años.
# 7	Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	La granja de los cuentos con Félix Jamacuco
# 2	2018-10-24 00:00:00.0-2018-10-24 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Dentro de la imaginería infantil ?el lobo? es un personaje querido, a la vez que temido. Siempre levanta sentimientos encontrados y siempre suscita curiosidad, pues es bien sabido que en todo relato que aparece uno o muchos lobos, será un relato que no nos dejará indiferentes.  Basándonos en la canción popular  ¡Me visto y te como!   y en el cuento popular  Sopa de piedra,  hemos creado un espectáculo de cuenta cuentos donde el humor, el juego, el ingenio del protagonista, la simpatía y la curiosidad y la buena voluntad del resto de los personajes crean un ambiente desenfadado y divertido.  Combinamos el simbolismo del lobo de los cuentos clásicos (astuto, mentiroso, pendenciero?) con el simbolismo del lobo de los cuentos modernos (bonachón, incomprendido, amigo de todo el mundo?) para crear una única historia y un lobo con múltiples personalidades.  De 3 a 8 años.
# 7	Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	La mar de viajes y aventuras con Nelson Calderón
# 2	2018-10-30 00:00:00.0-2018-10-30 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	De 4 a 7 años.
# 7	Biblioteca Pública Municipal San Blas (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	La mar de viajes y aventuras con Nelson Calderón
# 2	2018-10-30 00:00:00.0-2018-10-30 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	De 4 a 7 años.
# 7	Biblioteca Pública Municipal San Blas (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	Lobos y otros seres que llegan en invierno por Ana Griott
# 2	2018-11-27 00:00:00.0-2018-11-27 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Cuentos de lobos y de otros seres que se dejan ver cuando llega el frío y las noches se hacen largas.  En esas noches la gente se juntaba alrededor de la hoguera e imaginaba seres que aparecían en las sombras de la noche.El lobo era el más temido, sobre todo porque cazar en manada lo hacía más fuerte que cualquier animal.  A partir de 6 años.
# 7	Biblioteca Pública Municipal San Blas (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	Lobos y otros seres que llegan en invierno por Ana Griott
# 2	2018-11-27 00:00:00.0-2018-11-27 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Cuentos de lobos y de otros seres que se dejan ver cuando llega el frío y las noches se hacen largas.  En esas noches la gente se juntaba alrededor de la hoguera e imaginaba seres que aparecían en las sombras de la noche.El lobo era el más temido, sobre todo porque cazar en manada lo hacía más fuerte que cualquier animal.  A partir de 6 años.
# 7	Biblioteca Pública Municipal San Blas (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	Lobos y otros seres que llegan en invierno por Ana Griott
# 2	2018-12-12 00:00:00.0-2018-12-12 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Cuentos de lobos y de otros seres que se dejan ver cuando llega el frío y las noches se hacen largas.  En esas noches la gente se juntaba alrededor de la hoguera e imaginaba seres que aparecían en las sombras de la noche.El lobo era el más temido, sobre todo porque cazar en manada lo hacía más fuerte que cualquier animal.  A partir de 6 años.
# 7	Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	Lobos y otros seres que llegan en invierno por Ana Griott
# 2	2018-12-12 00:00:00.0-2018-12-12 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Cuentos de lobos y de otros seres que se dejan ver cuando llega el frío y las noches se hacen largas.  En esas noches la gente se juntaba alrededor de la hoguera e imaginaba seres que aparecían en las sombras de la noche.El lobo era el más temido, sobre todo porque cazar en manada lo hacía más fuerte que cualquier animal.  A partir de 6 años.
# 7	Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	Me visto del revés con Félix Jamacuco
# 2	2018-11-08 00:00:00.0-2018-11-08 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	Dentro de la imaginería infantil ?el lobo? es un personaje querido, a la vez que temido. Siempre levanta sentimientos encontrados y siempre suscita curiosidad, pues es bien sabido que en todo relato que aparece uno o muchos lobos, será un relato que no nos dejará indiferentes.  Basándonos en la canción popular  ¡Me visto y te como!   y en el cuento popular  Sopa de piedra,  hemos creado un espectáculo de cuenta cuentos donde el humor, el juego, el ingenio del protagonista, la simpatía y la curiosidad y la buena voluntad del resto de los personajes crean un ambiente desenfadado y divertido.  Combinamos el simbolismo del lobo de los cuentos clásicos (astuto, mentiroso, pendenciero?) con el simbolismo del lobo de los cuentos modernos (bonachón, incomprendido, amigo de todo el mundo?) para crear una única historia y un lobo con múltiples personalidades.  De 3 a 8 años.
# 7	Biblioteca Pública Municipal Canillejas (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños
# 1	Tan diferentes y tan iguales por  Nelson Calderón
# 2	2018-10-24 00:00:00.0-2018-10-24 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	De 4 a 7 años.
# 7	Biblioteca Pública Municipal Canillejas (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños
# 1	Tell me a story con Mert Clavero
# 2	2018-12-20 00:00:00.0-2018-12-20 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	La propuesta consiste en la lectura del libro en inglés ? Valle, Ana and the giraffe Tana? con la ayuda de marionetas de papel.  Después de la comprensión del texto cada participante sacará de distintas cajas palabras para formar nuestro propio cuento que inventaremos, aunque el cuento será sencillo seguro que surgen palabras nuevas que aprenderemos. Terminaremos la sesión ilustrando nuestra historia.  De 7 a 9 años.  Necesaria invitación previa, consultar en la biblioteca.
# 7	Biblioteca Pública Municipal Canillejas (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias
# 1	Tell me a story con Mert Clavero
# 2	2018-12-20 00:00:00.0-2018-12-20 23:59:00.0
# 3	--Indefinido--
# 4	--Indefinido--
# 5	18:00
# 6	La propuesta consiste en la lectura del libro en inglés ? Valle, Ana and the giraffe Tana? con la ayuda de marionetas de papel.  Después de la comprensión del texto cada participante sacará de distintas cajas palabras para formar nuestro propio cuento que inventaremos, aunque el cuento será sencillo seguro que surgen palabras nuevas que aprenderemos. Terminaremos la sesión ilustrando nuestra historia.  De 7 a 9 años.  Necesaria invitación previa, consultar en la biblioteca.
# 7	Biblioteca Pública Municipal Canillejas (San Blas-Canillejas)
# 8	/contenido/actividades/CuentacuentosTiteresMarionetas
# 9	/usuario/Niños,/usuario/Familias

# %% [markdown]
# ##### Ejercicio 2[3.5 puntos]
# Considerar el archivo __CentrosCulturas.json__ que incluye información sobre Centros Culturales, Socioculturales y Juveniles del Ayuntamiento de Madrid (incluídos aquellos en los que el Ayuntamiento es miembro del consorcio titular). También están incluidas las Salas de Estudio y Lectura. El fichero contiene los datos de localización (dirección, distrito y barrio), contacto, horario, servicios y actividades tipo que se pueden celebrar.
#
# El objetivo de este ejercicio es completar el ejercicio 1 para añadir información del centro cultural donde se realizan las actividades seleccionadas. Esta información se obtendrá del archivo __CentrosCulturales.json__.En este sentido, la modificación que se pide es añadir a la información que aparece en la pantalla sobre los eventos, información sobre el centro cultural: calle __[campo [address][street-address]]__, distrito postal __[campo [address][postal-code]]__,descripción del lugar __[ campo [organization][organization-desc]]__, accesibilidad __[ campo [organization][accesibility]]__ y servicios __[ campo [organization][services]]__.

# %% [markdown]
# Para leer los archivos usa un código como el siguiente:

# %%
import json
leer = json.loads(open('CentrosCulturales.json',encoding="utf8").read())
def ejercicioDos(centroCultural):
    for item in leer:
        if item["title"] == centroCultural:
            print("DATOS DEL CENTRO CULTURAL: ")
            print(item["address"]["street-address"])
            print(item["address"]["postal-code"])
            print(item["organization][organization-desc]"])
            print(item["organization"]["accesibility"])
            print(item["organization"]["services"])

# %% [markdown]
# #### Ejercicio 3[1.5 puntos]
# El objetivo de este ejercicio es completar el ejercicio 1 para mejorar la búsqueda realizada. En este sentido, habría que añadir una nueva pregunta:
# * Quinta pregunta. Distancia. Se preguntará al usuario que introduzca una longitud, una latitud y un número real que representa una distancia en kilometros. Así, el programa además de seleccionar por los criterios anteriores, tendrá en cuenta la distancia entre el lugar de realización del evento y la localización introducida, de manera que si esta distancia es mayor que la distancia introducida por el usuario, entonces el evento no se mostrará.
#
# Otro cambio que habrá que hacer es mostrar en los eventos resultantes un campo de información sobre la distancia cálculada.
#
# La información sobre la localización en términos de latitud y longitud del centro cultural se puede obtener tanto en el archivo __CentrosCulturales.json__ o __Agenda.json__. Por otro lado para calcular la distancia entre dos puntos dadas sus coordenadas se utilizará la siguiente función en Python:

# %% [raw]
# import math
#
# def haversine(lat1, lon1, lat2, lon2):
#     rad=math.pi/180
#     dlat=lat2-lat1
#     dlon=lon2-lon1
#     R=6372.795477598
#     a=(math.sin(rad*dlat/2))**2 + math.cos(rad*lat1)*math.cos(rad*lat2)*(math.sin(rad*dlon/2))**2
#     distancia=2*R*math.asin(math.sqrt(a))
#     return distancia

# %%
#TODO cambiar los diccionarios para leer las latitudes y las longitudes y los demas datos
#Escribir los datos en la lista evento
def ejercicioTres(distritos, distrito, actividad, audiencia):
    lista = []
    displayAndList(lista, distritos[distrito][actividad][audiencia].keys(), 3)
    listaAux = distritos[distrito][actividad][audiencia].keys()
    longitud = checkCorrectness("longitud")
    latitud = checkCorrectness("latitud")
    distanciaUsuario = checkCorrectness("distancia en Km")
    dist = haversine(longitud, latitud,  listaAux[0], listaAux[1])

    if (dist < distanciaUsuario) :
        #Mostrar la distancia calculada
        print(dist)
        #Mostrar el evento
        evento = []
        #evento[0] = Titulo
        #evento[1] = Fecha de inicio y finalizacion
        #evento[2] = Dias de la semana
        #evento[3] = Dias excluidos
        #evento[4] = Hora
        #evento[5] = Descripcion
        #evento[6] = Nombre de instalacion
        #evento[7] = Tipo de audiencia
        #evento[8] = Audiencia
        displayEvent(evento)
        ejercicioDos(evento[6])
    else:
        print("Error\n")

# %% [markdown]
# #### Normas de entrega
#
# * Fecha tope de entrega: 11/10/2018
# * La entrega se realizará subiendo al campus virtual un notebook de Jupyter con la solución. El archivo tendrá como nombre FormatosI_GrupoX donde X será el número de grupo correspondiente.
